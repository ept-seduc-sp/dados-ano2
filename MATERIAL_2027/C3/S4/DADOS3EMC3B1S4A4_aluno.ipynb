# %% [markdown]
# <h1 align="center">TÉCNICO EM CIÊNCIA DE DADOS</h1>
#
# <h2 align="center">Roteiro de Atividade Prática</h2>
#
# <br>
#
# **Componente:** Análise Exploratória de Dados e Inteligência de Negócios
# **Unidade Curricular:** Análise Exploratória de Dados
# **Tema da Semana:** Visualização Exploratória de Dados
# **Semana 4**
# **Aula 4:** Análise de padrões em visualizações
#
# <br>

# %% [markdown]
# # Análise de padrões, tendências e exceções em visualizações do comércio varejista
#
# **Situação profissional**
#
# Você atua como auxiliar de dados em uma consultoria que acompanha o comércio varejista
# brasileiro. O gestor prepara um briefing sobre o desempenho do varejo nos últimos 13 meses
# e já recebeu três visualizações construídas a partir da **Pesquisa Mensal de Comércio (PMC),
# do IBGE**. Ele não quer novos gráficos: quer a leitura deles.
#
# A pergunta que ele fez foi esta:
#
# > Compare **vestuário** e **informática**: como os valores mais altos do período se comportam
# > ao longo da série? Eles indicam **recorrência no recorte observado** ou uma **mudança
# > concentrada no fim do período**? Justifique com evidências das visualizações e dos dados.
#
# Nesta atividade o código já está pronto. Sua tarefa não é construir gráficos: é **executar,
# verificar os valores e analisar** o que as visualizações mostram, registrando conclusões
# fundamentadas nos dados observados.
#
# **Fluxo de trabalho**
#
# **executar → verificar → analisar → concluir**
#
# **Ambiente recomendado:** Visual Studio Code (VS Code), com suporte a arquivos `.ipynb`.
# **Alternativa:** o professor poderá orientar o uso do Google Colab.

# %% [markdown]
# ## 1. Preparação
#
# Arquivos usados nesta atividade:
#
# - `DADOS3EMC3B1S4A4_aluno.ipynb`
# - `DADOS3EMC3B1S4A4_PMC_IBGE.csv`
#
# 1. Baixe os dois arquivos e salve-os **na mesma pasta**.
# 2. Abra o arquivo `.ipynb` no **Visual Studio Code**.
# 3. Se solicitado, selecione um **kernel Python** disponível.
# 4. Execute a célula abaixo para carregar os dados.
#
# > Se o professor optar pelo Google Colab, faça o upload do arquivo CSV para a sessão antes
# > de executar a célula.
#
#
# > **Compatibilidade do Matplotlib.** O **Gráfico 3 (boxplot)** usa o parâmetro `tick_labels`, disponível no **Matplotlib 3.9 ou superior**. Se essa célula apresentar erro relacionado a `tick_labels`, não altere o código: avise o professor para verificar a versão instalada.

# %%
import pandas as pd
import matplotlib.pyplot as plt

dados = pd.read_csv("DADOS3EMC3B1S4A4_PMC_IBGE.csv").sort_values("ordem_mes")
dados.head()

# %% [markdown]
# ## 2. Como ler as variáveis
#
# - `mes` — mês de referência, de dezembro de 2024 a dezembro de 2025 (13 meses).
# - `ordem_mes` — número de 1 a 13, usado apenas para manter os meses na ordem correta.
# - `atividade` — atividade do comércio varejista.
# - `indice_volume` — índice de base fixa do volume de vendas.
#
# **Atenção à unidade.** O índice **não é porcentagem de variação**. Na Tabela 5 usada nesta
# atividade, a base é **2014 = 100**. Um valor de 170 indica volume 70% acima dessa referência;
# um valor de 95 indica volume 5% abaixo dela.
#
# A atividade focaliza duas das nove séries do conjunto:
#
# - **Tecidos, vestuário e calçados** — chamada de "vestuário" ao longo do roteiro.
# - **Informática e comunicação** — chamada de "informática" ao longo do roteiro.

# %%
# Separa as duas atividades analisadas nesta aula.
vestuario = dados[dados["atividade"] == "Tecidos, vestuário e calçados"]
informatica = dados[dados["atividade"] == "Informática e comunicação"]

print("Linhas de vestuário:", len(vestuario))
print("Linhas de informática:", len(informatica))

# %% [markdown]
# ## Etapa 1 — Executar e observar
#
# Execute as três células a seguir. Cada uma gera uma das visualizações que o gestor recebeu.
# Nesta etapa você apenas **observa**: ainda não é hora de concluir nada.

# %%
# GRÁFICO 1 — linha: o índice das duas atividades ao longo dos 13 meses.
plt.figure(figsize=(11, 4.5))

for atividade in ["Tecidos, vestuário e calçados", "Informática e comunicação"]:
    serie = dados[dados["atividade"] == atividade]
    plt.plot(serie["mes"], serie["indice_volume"], marker="o", label=atividade)

plt.xlabel("Mês")
plt.ylabel("Índice de volume de vendas (2014 = 100)")
plt.title("Gráfico 1 — Volume de vendas mês a mês")
plt.xticks(rotation=40, ha="right")
plt.legend()
plt.grid(axis="y", linewidth=0.3)
plt.tight_layout()
plt.show()

# %%
# GRÁFICO 2 — barras: as oito atividades do varejo em dezembro de 2025.
dez = dados[(dados["mes"] == "dez/2025") & (dados["atividade"] != "Comércio varejista (total)")]

plt.figure(figsize=(10, 4.5))
plt.bar(dez["atividade"], dez["indice_volume"])

plt.xlabel("Atividade")
plt.ylabel("Índice de volume de vendas (2014 = 100)")
plt.title("Gráfico 2 — Volume de vendas por atividade em dez/2025")
plt.xticks(rotation=35, ha="right")
plt.grid(axis="y", linewidth=0.3)
plt.tight_layout()
plt.show()

# %%
# GRÁFICO 3 — boxplot: a distribuição dos 13 índices de cada atividade.
plt.figure(figsize=(7, 4.5))
plt.boxplot([vestuario["indice_volume"], informatica["indice_volume"]],
            tick_labels=["Vestuário", "Informática"])

plt.ylabel("Índice de volume de vendas (2014 = 100)")
plt.title("Gráfico 3 — Distribuição dos 13 índices mensais")
plt.grid(axis="y", linewidth=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Registro 1 — o que cada gráfico representa
#
# Complete a tabela abaixo. Escreva diretamente nesta célula (clique duas vezes para editar).
#
# | Gráfico | Variáveis representadas | Unidade do eixo vertical |
# |---|---|---|
# | 1 — linha | | |
# | 2 — barras | | |
# | 3 — boxplot | | |

# %% [markdown]
# ## Etapa 2 — Identificar padrões e tendências
#
# Volte ao **Gráfico 1**. Descreva, em **uma frase para cada atividade**, como o índice se
# comporta ao longo dos 13 meses. Descreva o comportamento no tempo, não um valor isolado.

# %% [markdown]
# ### Registro 2 — padrão de cada atividade
#
# **Vestuário:**
#
# **Informática:**

# %% [markdown]
# ## Etapa 3 — Comparar as diferenças entre os grupos
#
# Execute a célula abaixo. Ela resume as duas distribuições. Use as linhas **min**, **50%**
# (a mediana) e **max** — são os valores que aparecem no **Gráfico 3** (boxplot).
#
# Use esses números junto com o **Gráfico 2** para preencher o Registro 3.

# %%
resumo = pd.DataFrame({
    "vestuario": vestuario["indice_volume"].describe(),
    "informatica": informatica["indice_volume"].describe(),
})
resumo.round(1)

# %% [markdown]
# ### Registro 3 — comparação entre as duas atividades
#
# Preencha com **uma casa decimal**.
#
# | | Vestuário | Informática |
# |---|---|---|
# | Índice em dez/2025 (Gráfico 2) | | |
# | Mediana dos 13 meses | | |
# | Valor mínimo | | |
# | Valor máximo | | |
#
# **Qual das duas distribuições apresenta maior amplitude de valores (máximo − mínimo)?**
# Responda com o nome da atividade e justifique citando o mínimo e o máximo de cada uma.
#
# **Resposta:**

# %% [markdown]
# ## Etapa 4 — Reconhecer possíveis exceções
#
# No **Gráfico 3**, as duas atividades apresentam pontos desenhados **separadamente, acima da
# haste superior** da caixa. São valores que se afastam do restante da distribuição.
#
# > **Atenção.** Um ponto pode representar mais de um mês, quando dois meses têm o mesmo valor.
# > Por isso não conte os pontos do gráfico: use a célula abaixo para descobrir **quais meses**
# > são esses.
#
# A célula calcula o limite superior do boxplot para cada atividade e lista os meses acima dele.

# %%
def meses_afastados(tabela):
    """Devolve os meses cujo índice fica acima da haste superior do boxplot."""
    q1 = tabela["indice_volume"].quantile(0.25)
    q3 = tabela["indice_volume"].quantile(0.75)
    limite_superior = q3 + 1.5 * (q3 - q1)
    acima = tabela[tabela["indice_volume"] > limite_superior]
    return round(limite_superior, 1), acima[["mes", "indice_volume"]]

limite_v, afastados_v = meses_afastados(vestuario)
limite_i, afastados_i = meses_afastados(informatica)

print("VESTUÁRIO — limite superior:", limite_v)
print(afastados_v.to_string(index=False))
print()
print("INFORMÁTICA — limite superior:", limite_i)
print(afastados_i.to_string(index=False))

# %% [markdown]
# ### Verificação: o mesmo mês do ano anterior
#
# Os meses que você encontrou estão no fim da série. Para verificar se um valor alto em
# dezembro **reaparece no mesmo mês observado no ano anterior**, é preciso comparar dezembro
# com dezembro.
#
# A série começa em **dez/2024** e termina em **dez/2025**, então o único par de meses iguais
# em anos diferentes é **dezembro**.
#
# Na célula abaixo, complete a linha indicada substituindo `____` pelo mês que deve ser
# comparado com `dez/2025`. Escreva exatamente como aparece na coluna `mes`.

# %%
# COMPLETE: escreva entre aspas o mês do ano anterior que corresponde a dez/2025.
mes_anterior = "____"

comparacao = dados[dados["mes"].isin([mes_anterior, "dez/2025"])]
comparacao = comparacao[comparacao["atividade"].isin(
    ["Tecidos, vestuário e calçados", "Informática e comunicação"])]

comparacao.pivot(index="atividade", columns="mes", values="indice_volume")

# %% [markdown]
# ### Registro 4 — exceções e verificação
#
# Preencha com os meses no formato `mmm/aaaa` e os valores com uma casa decimal.
#
# | Atividade | Meses afastados | Valores | Valor em dez/2024 | Há valor alto também em dez/2024? (sim/não) |
# |---|---|---|---|---|
# | Vestuário | | | | |
# | Informática | | | | |
#
# **Em uma frase, explique por que um valor afastado não significa, por si só, que houve erro
# nos dados.**
#
# **Resposta:**

# %% [markdown]
# ## Etapa 5 — Roteiro de análise visual
#
# Este é o **produto da atividade**. **Integre** as evidências dos três gráficos e **explique**
# a diferença entre as duas atividades usando somente o que você observou nas visualizações e
# verificou nos dados. Não use informação de fora do conjunto.
#
# | Campo | Registro da dupla |
# |---|---|
# | **Gráficos analisados** | |
# | **Padrão ou tendência identificada em vestuário** | |
# | **Padrão ou tendência identificada em informática** | |
# | **Evidências observadas** — linha: meses e valores; barras: atividade e índice em dez/2025; boxplot: mediana, faixa de valores e/ou pontos afastados confirmados pela célula | |
# | **Interpretação dos resultados** — explique o que a diferença entre as duas atividades indica no recorte observado | |
# | **Possíveis limitações da análise** — o que estes gráficos não permitem afirmar | |
# | **Conclusão justificada para o gestor** — responda à pergunta dele em 2 ou 3 frases | |

# %% [markdown]
# ## Critérios para avaliação da atividade
#
# - Identificação das variáveis e da unidade representadas em cada visualização.
# - Descrição do padrão de cada atividade a partir do gráfico de linha.
# - Comparação entre as duas distribuições com uso dos valores do boxplot e do gráfico de barras.
# - Identificação dos meses afastados e verificação do mesmo mês do ano anterior disponível na série.
# - **Integração** de evidências dos três gráficos no roteiro de análise visual.
# - Distinção entre recorrência no recorte observado e mudança recente, sem extrapolar o que os dados permitem afirmar.
# - Conclusão fundamentada nos dados observados, com limitação declarada.
#
# **Entrega:** este notebook preenchido e salvo, por dupla, ao final da atividade.

# %% [markdown]
# ---
#
# **Fonte dos dados**
#
# INSTITUTO BRASILEIRO DE GEOGRAFIA E ESTATÍSTICA (IBGE). *Pesquisa Mensal de Comércio*:
# Tabela 5 — Índice de base fixa do volume de vendas no comércio varejista, por atividades.
# Dezembro de 2025. Rio de Janeiro: IBGE, 2026. Disponível em:
# https://ftp.ibge.gov.br/Comercio_e_Servicos/Pesquisa_Mensal_de_Comercio/Fasciculo_Indicadores_IBGE/2025/pmc_202512caderno.pdf.
# Acesso em: 30 ago. 2026.
#
# *Adaptação didática: recorte de nove séries (comércio varejista total e oito atividades) da
# Tabela 5, de dez/2024 a dez/2025, reorganizado em formato tidy. A análise focaliza vestuário
# e informática; o gráfico de barras compara as oito atividades em dez/2025. Os valores foram
# preservados sem alteração.*
