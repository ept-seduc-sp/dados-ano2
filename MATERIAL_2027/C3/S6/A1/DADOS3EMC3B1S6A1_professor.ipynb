# %% [markdown]
# <h1 align="center">TÉCNICO EM CIÊNCIA DE DADOS</h1>
#
# <h2 align="center">Roteiro de Atividade Prática</h2>
#
# <br>
#
# **Componente:** Análise Exploratória de Dados e Inteligência de Negócios
# **Unidade Curricular:** Projeto Análise Exploratória de Dados
# **Tema da Semana:** Projeto de Análise Exploratória de Dados: Planejamento e Exploração Inicial
# **Semana 6**
# **Aula 1:** Definição do problema de análise
#
# <br>

# %% [markdown]
# # Definição do problema de análise: o que os dados permitem investigar?
#
# **Situação profissional**
#
# Vocês atuam como **assistentes de dados da equipe comercial** de uma pequena rede de lojas de materiais para escritório.
#
# A gerência observou diferenças entre as lojas na quantidade de entradas de pessoas, nas compras registradas e nos valores obtidos com as vendas. A rede já destina recursos à divulgação, ao atendimento, à disponibilidade de produtos e às campanhas de desconto.
#
# Essas diferenças preocupam a gerência porque ela precisa decidir **em qual dessas frentes concentrar tempo e recursos para planejar uma primeira ação de melhoria**. Escolher uma prioridade apenas por impressão pode direcionar esforços para um aspecto que não seja o mais relevante para o problema.
#
# A equipe de dados foi chamada para reunir evidências que ajudem a orientar essa decisão. Ao longo das quatro aulas, vocês examinarão os dados e apresentarão uma recomendação inicial, explicando o que a sustenta e quais dúvidas permanecem.
#
# Nesta primeira etapa, vocês vão conhecer o conjunto, verificar pontos de atenção e **escolher, entre perguntas propostas, uma pergunta investigativa adequada para orientar este projeto**.
#
# **Missão da aula**
#
# > **Aplicar critérios para escolher e justificar uma pergunta investigativa adequada para orientar este projeto de AED.**

# %% [markdown]
# ## Preparação
#
# Arquivos usados nesta atividade:
#
# - `DADOS3EMC3B1S6A1_professor.ipynb`
# - `dados_simulados_rede_papelarias.csv`
#
# 1. Salvem os dois arquivos **na mesma pasta**.
# 2. Abram o arquivo `.ipynb` no **Visual Studio Code**.
# 3. Se solicitado, selecionem um **kernel Python** disponível.
# 4. Executem a célula abaixo para carregar os dados.
#
#
# > Se o professor optar pelo Google Colab, façam o upload do CSV para a sessão antes de executar a célula.

# %%
from pathlib import Path
import pandas as pd
from IPython.display import display

arquivo_csv = Path("dados_simulados_rede_papelarias.csv")


if not arquivo_csv.is_file():
    candidatos = sorted(Path.cwd().glob("dados_simulados_rede_papelarias.csv"))
    if len(candidatos) != 1:
        raise FileNotFoundError(
            "Deixe o CSV desta atividade na pasta de execução do notebook. "
            "No Colab, envie o CSV para a sessão."
        )
    arquivo_csv = candidatos[0]

dados = pd.read_csv(arquivo_csv)

print("Arquivo carregado:", arquivo_csv.name)
print("Quantidade de registros:", len(dados))
print("Quantidade de colunas:", dados.shape[1])
display(dados.head())

# %% [markdown]
# ## Etapa 1 — Conheçam as informações disponíveis
#
# Cada registro reúne informações de **uma loja em um dia de funcionamento**.
#
# | Coluna | Informação registrada |
# |---|---|
# | `id_registro` | Código que identifica o registro. |
# | `data` | Data de funcionamento registrada. |
# | `loja` | Código da loja. |
# | `entradas` | Quantidade de entradas de pessoas na loja durante o dia. |
# | `horas_equipe` | Soma das horas trabalhadas pela equipe de atendimento no dia. |
# | `investimento_divulgacao` | Valor investido em divulgação local naquele dia, em reais. |
# | `canal_divulgacao` | Canal principal de divulgação do dia; “Sem divulgação” indica dias sem investimento registrado. |
# | `desconto_campanha_pct` | Percentual de desconto anunciado para os produtos participantes da campanha; não se aplica necessariamente a todos os itens vendidos. |
# | `disponibilidade_produtos_pct` | Percentual dos produtos monitorados disponíveis na abertura da loja. |
# | `espera_media_min` | Tempo médio, em minutos, até o primeiro atendimento. |
# | `cupons_emitidos` | Quantidade de transações registradas no dia. |
# | `receita_liquida` | Valor registrado nas vendas do dia após descontos comerciais, em reais. |
# | `lucro_bruto` | Receita líquida menos o custo das mercadorias vendidas. Não representa o lucro final da loja. |
#
# **Atenção:** entradas e cupons representam contagens de entradas e de transações; não identificam clientes únicos.
#
# **Referência técnica para `lucro_bruto`:**
# COMITÊ DE PRONUNCIAMENTOS CONTÁBEIS (CPC). *CPC 26 (R1) — Apresentação das Demonstrações Contábeis*, item 103.
# [Documento de referência, item 103](https://www.cpc.org.br/Arquivos/Documentos/312_CPC_26_R1_rev%2023.pdf).
#
# ### Registro 1 — reconheçam a estrutura
#
# **1. O que cada registro representa?**
#
# **Resposta:**
#
#
# **2. Qual coluna identifica cada registro?**
#
# **Resposta:**
#
#
# **3. Escolham uma variável quantitativa e uma variável qualitativa do conjunto. O que cada uma registra?**
#
# **Resposta:**

# %% [markdown]
# ## Etapa 2 — Verifiquem pontos de atenção
#
# Antes de escolher uma pergunta para o projeto, verifiquem se há registros repetidos ou informações ausentes.
#
# Executem a célula abaixo e examinem as saídas.

# %%
# Verificação de registros repetidos
copias_duplicadas = dados.duplicated().sum()
print("Cópias duplicadas encontradas:", copias_duplicadas)

if copias_duplicadas > 0:
    print("\nRegistros envolvidos na duplicação:")
    display(dados[dados.duplicated(keep=False)].sort_values(["id_registro", "data"]))

# Verificação de valores ausentes
ausentes = dados.isna().sum()
ausentes = ausentes[ausentes > 0].to_frame("valores_ausentes")

print("\nColunas com valores ausentes:")
display(ausentes)

# %% [markdown]
# ### Registro 2 — interpretem os pontos de atenção
#
# **4. A cópia duplicada acrescenta uma nova observação sobre a operação das lojas? Qual decisão é adequada antes de continuar?**
#
# **Resposta:**
#
#
# **5. Os valores ausentes em `espera_media_min` significam que o tempo de espera foi zero nesses dias? Explique.**
#
# **Resposta:**
#
#
# **6. Quando `espera_media_min` for necessária em uma análise posterior, quais registros poderão ser usados nessa análise? Por que os registros com espera ausente devem ser preservados para análises de outras variáveis?**
#
# **Resposta:**
#
#
# Depois de registrar as respostas, executem a próxima célula. O código retira somente a **cópia duplicada**. Os registros com espera ausente são preservados porque os valores das demais variáveis nesses registros são válidos para uso em análises que utilizem essas variáveis e não dependam da espera. A ausência de espera, por si só, não justifica excluir o registro inteiro.

# %%
# Conjunto de trabalho para as próximas etapas
dados_trabalho = dados.drop_duplicates().copy()

print("Registros no conjunto original:", len(dados))
print("Registros únicos para o trabalho:", len(dados_trabalho))
print(
    "Registros com espera disponível:",
    dados_trabalho["espera_media_min"].notna().sum()
)
print(
    "Registros com espera ausente:",
    dados_trabalho["espera_media_min"].isna().sum()
)

# %% [markdown]
# ## Etapa 3 — Avaliem as perguntas candidatas a orientar este projeto
#
# Uma pergunta investigativa adequada para orientar **este projeto de AED** precisa atender, em conjunto, a quatro critérios:
#
# 1. **Suficiência dos dados:** todas as informações necessárias para responder à pergunta devem poder ser extraídas do conjunto de dados fornecido.
# 2. **Alcance da AED:** a pergunta não deve exigir que a AED conclua uma relação de causa e efeito.
# 3. **Atendimento ao problema profissional:** a pergunta deve ser suficiente para atender ao problema profissional apresentado.
# 4. **Orientação da investigação:** a pergunta deve ser ampla o suficiente para orientar e justificar todas as ações da investigação nas próximas etapas do projeto.
#
# Essas ações incluem selecionar variáveis, escolher medidas e representações, comparar grupos, examinar relações e integrar evidências para elaborar uma recomendação inicial à gerência.
#
# #### Observação ####
# > Neste projeto, considerar o conjunto de dados suficiente significa que ele permite realizar as análises necessárias para responder à pergunta investigativa e fundamentar uma recomendação inicial de prioridade para a rede. Essa recomendação deve reunir as evidências encontradas e explicitar os limites das conclusões. Não se exige demonstrar que a ação recomendada causará uma melhoria, garantirá aumento do lucro ou será a melhor entre todas as ações possíveis.
#
# Considerem as quatro perguntas candidatas a orientar este projeto:
#
#
# **A.** Quais condições estão associadas ao desempenho comercial das lojas e qual aspecto merece prioridade para uma primeira ação de melhoria?
#
# **B.** Como o investimento em divulgação se relaciona com o número de entradas nas lojas?
#
# **C.** A experiência profissional da equipe está associada ao desempenho comercial das lojas?
#
# **D.** Qual canal de divulgação é mais eficaz para aumentar o lucro bruto?

# %% [markdown]
# ### Registro 3 — comparem as perguntas candidatas a orientar este projeto
#
# Preencham cada espaço com **Sim** ou **Não**, considerando os critérios separadamente. Verifiquem se cada pergunta atende ao problema profissional e permite orientar o projeto completo. Tratar de um assunto relevante para a empresa, por si só, não é suficiente.
#
# | Critério | A | B | C | D |
# |---|---|---|---|---|
# | Todas as informações necessárias para responder à pergunta podem ser extraídas do conjunto de dados fornecido? | | | | |
# | A pergunta pode ser respondida sem exigir que a AED conclua uma relação de causa e efeito? | | | | |
# | A pergunta é suficiente para atender ao problema profissional apresentado? | | | | |
# | A pergunta é ampla o suficiente para orientar e justificar todas as ações da investigação nas próximas etapas do projeto? | | | | |
#
# > Uma pergunta específica pode ser adequada para uma parte da análise e funcionar como subpergunta. Aqui, vocês devem escolher uma pergunta suficiente para atender ao problema profissional e orientar todas as ações da investigação deste projeto.

# %% [markdown]
# ## Etapa 4 — Escolham uma pergunta adequada para orientar este projeto
#
# ### Registro 4 — decisão da dupla
#
# **7. Qual das perguntas propostas atende aos quatro critérios e é adequada para orientar este projeto?**
#
# **Resposta:**
#
#
# **8. Justifiquem a escolha aplicando os quatro critérios. Expliquem por que o conjunto de dados fornecido é suficiente para responder à pergunta, sem exigir uma conclusão de causa e efeito, e por que a pergunta atende ao problema profissional e orienta as ações da investigação. Citem variáveis do conjunto para sustentar a justificativa.**
#
# **Justificativa:**

# %% [markdown]
# ## Critérios para avaliação da atividade
#
# - Reconhece o que cada registro representa e identifica informações disponíveis no conjunto.
# - Interpreta corretamente a duplicação e os valores ausentes como pontos de atenção.
# - Examina as perguntas candidatas aplicando os quatro critérios de adequação a este projeto.
# - Escolhe uma pergunta adequada para orientar este projeto e justifica a suficiência dos dados, o alcance da AED, o atendimento ao problema e a orientação das ações da investigação.
# - Registra uma expectativa inicial coerente com os dados e com o problema profissional.
#
# **Entrega:** salvem este notebook preenchido. Na próxima aula, retomem a pergunta escolhida, a justificativa, a expectativa e os cuidados com os registros.

# %% [markdown]
# ---
#
# **Sobre os dados**
#
# O conjunto foi elaborado para fins didáticos e simula registros de operação diária de uma pequena rede de lojas. Os resultados obtidos nesta atividade descrevem somente este conjunto e não devem ser generalizados para empresas reais.

# %% [markdown]
# ---
#
# # Gabarito e orientações para o professor
#
# > Esta seção existe **apenas no notebook do professor**. O notebook do estudante termina na informação sobre a natureza dos dados.

# %% [markdown]
# ## Organização e tempo
#
# Referência para os **43 minutos** de Colocando em prática:
#
# - 4 min — leitura do caso, abertura do notebook e carga dos dados;
# - 7 min — leitura orientada do conjunto e Registro 1;
# - 9 min — verificação de duplicação e ausências + Registro 2;
# - 10 min — comparação das perguntas candidatas;
# - 8 min — escolha e justificativa da pergunta;
# - 5 min — registro da expectativa inicial, revisão rápida e salvamento.
#
# O registro deve ocorrer ao longo da atividade. Não concentre a escrita nos minutos finais.
#
# Antes da aula, teste a abertura do notebook e a leitura do CSV no ambiente da turma, com Python e pandas disponíveis. A instalação de ferramentas não está incluída nos 43 minutos. No Colab, o upload do CSV deve ocorrer antes da carga.
#
# Compartilhe com a turma somente a versão do aluno. O tempo indicado é uma previsão de planejamento; a duração real depende da familiaridade da turma com o ambiente.

# %% [markdown]
# ## Condução
#
# O objetivo da aula é **aplicar critérios para selecionar uma pergunta investigativa adequada para orientar este projeto**. A resposta ao problema comercial será construída ao longo das quatro aulas.
#
# Na leitura do caso, destaque o problema observado, a necessidade de priorizar tempo e recursos e a função da equipe de dados. As diferenças mencionadas contextualizam a demanda; não demonstram que uma loja aproveita mal o movimento, nem que divulgação, atendimento, estoque ou desconto explicam seu desempenho.
#
# Use o notebook também como **revisão implícita** dos conteúdos anteriores. A classificação de uma variável qualitativa e de uma quantitativa retoma tipos de dados; a duplicação e as ausências retomam qualidade; a leitura do conjunto retoma registro, coluna e variável. Intervenha brevemente quando uma dúvida impedir o avanço.
#
# Reserve o **Relembre** para os conceitos estruturantes da etapa: papel da pergunta no ciclo de AED, relação entre pergunta e dados disponíveis e viabilidade investigativa.
#
# Na Etapa 2, peça que as duplas interpretem as saídas antes de executar a correção preparada. A programação é instrumental: os estudantes não precisam escrever comandos para localizar ou remover duplicações. Esta é uma triagem de duplicação e ausências; não representa uma certificação completa da qualidade dos dados.
#
# Não introduza imputação. Espera ausente significa **informação desconhecida**, não zero. Quando uma análise precisar dessa variável, utilize os registros com espera disponível e informe a quantidade utilizada. Preserve os registros com espera ausente: os valores das demais variáveis nesses registros são válidos para uso em análises que utilizem essas variáveis e não dependam da espera. Excluir o registro inteiro eliminaria informações válidas sem necessidade. Neste conjunto, o registro de ocorrências documenta falhas de medição; em outro conjunto, a origem das ausências precisaria ser verificada antes de avaliar seus efeitos sobre a interpretação.
#
# Na Etapa 3, peça que avaliem cada critério separadamente. A evidência de aprendizagem está na **justificativa com base nos dados e na formulação das perguntas**, não apenas na letra escolhida. Diferencie os critérios 3 e 4: o terceiro verifica se a pergunta atende ao problema de definir uma prioridade inicial para a rede; o quarto verifica se ela orienta e justifica as ações necessárias para construir essa resposta ao longo do projeto. Essa abrangência é uma exigência deste projeto de quatro aulas, não uma regra para qualquer pergunta de AED.
#
# Na Etapa 5, cada dupla escolhe uma das relações já propostas e registra uma expectativa provisória. Essa escolha não cria um percurso diferente para cada dupla: todas seguirão as perguntas guiadas das aulas seguintes. Não avalie a expectativa pelo acerto de sua direção nem revele os resultados posteriores.
#
# Ao final, confirme que todas as duplas compreenderam a pergunta principal e conseguiram salvá-la com a justificativa, a expectativa e os cuidados com os dados. Esses registros serão retomados na A2.

# %% [markdown]
# ## Expectativas de respostas
#
# ### Registro 1 — estrutura
#
# **1. O que cada registro representa?**
# Cada registro representa **uma loja em um dia de funcionamento**.
#
# **2. Qual coluna identifica cada registro?**
# `id_registro`.
#
# **3. Exemplo de classificação:**
# - quantitativa (numérica): `entradas`, pois representa a **contagem do número de entradas de pessoas na loja em um dia de funcionamento**;
# - qualitativa: `canal_divulgacao`, pois identifica, por categorias, o canal principal de divulgação utilizado no dia.
#
# Aceite outros exemplos corretos. Não transforme este item em revisão extensa das subdivisões dos tipos de dados.

# %% [markdown]
# ### Registro 2 — pontos de atenção
#
# **4. Duplicação:**
# A cópia duplicada não acrescenta uma nova observação. A decisão adequada é retirar somente a cópia repetida antes de continuar, preservando um dos registros.
#
# **5. Valores ausentes de espera:**
# Não significam espera igual a zero. Indicam que a informação de espera não está disponível nesses registros.
#
# **6. Uso posterior da espera:**
# Quando uma análise exigir `espera_media_min`, utilizar somente os registros em que essa informação está disponível. Os registros com espera ausente devem permanecer no conjunto de trabalho porque os valores das demais variáveis nesses registros são válidos para uso em outras análises que utilizem essas variáveis e não dependam da espera. Portanto, a ausência de espera não justifica excluir o registro inteiro: isso eliminaria informações válidas sem necessidade.
#
# Após `drop_duplicates()`, o conjunto de trabalho contém **5.000 registros únicos**. Desses, **4.976** têm `espera_media_min` disponível e **24** mantêm a informação ausente.
#
# A exclusão preparada usa igualdade em **todas as colunas**. A coincidência de loja, data ou identificador, isoladamente, exigiria conferir os registros antes de decidir. No arquivo desta atividade, o registro de ocorrências confirma uma cópia repetida na exportação.

# %% [markdown]
# ### Registro 3 — perguntas candidatas a orientar este projeto
#
# Preenchimento esperado, considerando cada critério separadamente:
#
# | Critério | A | B | C | D |
# |---|---|---|---|---|
# | Todas as informações necessárias para responder à pergunta podem ser extraídas do conjunto de dados fornecido? | Sim | Sim | Não | Não |
# | A pergunta pode ser respondida sem exigir que a AED conclua uma relação de causa e efeito? | Sim | Sim | Sim | Não |
# | A pergunta é suficiente para atender ao problema profissional apresentado? | Sim | Não | Não | Não |
# | A pergunta é ampla o suficiente para orientar e justificar todas as ações da investigação nas próximas etapas do projeto? | Sim | Não | Não | Não |
#
# **A — Adequada para orientar este projeto.** Todas as informações necessárias para construir a resposta exploratória prevista podem ser extraídas do conjunto fornecido: movimento, compras, condições de atendimento, divulgação, disponibilidade de produtos e resultado comercial. A pergunta permite investigar associações sem exigir que a AED conclua uma relação de causa e efeito. É suficiente para atender ao problema de indicar uma prioridade inicial à gerência e permite orientar e justificar a seleção de variáveis, as medidas e representações, as comparações entre grupos, o exame de relações e a integração das evidências.
#
# O atendimento ao problema consiste em apresentar uma **recomendação inicial fundamentada e delimitada pelas evidências**. Os dados não precisam demonstrar um ganho garantido ou uma ação ótima para cumprir essa finalidade. Exigir essas conclusões mudaria a pergunta e ultrapassaria a suficiência atribuída ao conjunto.
#
# **B — Adequada como subpergunta, mas insuficiente para orientar este projeto completo.** Todas as informações necessárias para examinar a associação entre investimento e entradas podem ser extraídas do conjunto, sem concluir causa e efeito. Entretanto, responder apenas sobre essa relação não é suficiente para atender ao problema de definir a prioridade da rede considerando também as compras e o resultado comercial. A pergunta tampouco orienta e justifica todas as ações previstas na investigação dessas outras frentes.
#
# **C — Inadequada para orientar este projeto com o conjunto fornecido.** A pergunta não exige uma conclusão de causa e efeito, mas a experiência profissional da equipe não está registrada. `horas_equipe` representa as horas trabalhadas no dia e não informa a experiência profissional. Além da falta desse dado, a pergunta trata de uma relação específica e não é suficiente para atender ao problema completo nem orientar todas as ações da investigação prevista.
#
# **D — Inadequada para orientar este projeto como está formulada.** O conjunto contém canal de divulgação e lucro bruto, mas a existência dessas colunas não fornece todas as informações necessárias para demonstrar qual canal é mais eficaz para aumentar o lucro. Essa formulação exige uma conclusão sobre causa e efeito. Também restringe a investigação aos canais de divulgação, sendo insuficiente para atender ao problema completo e justificar as análises das outras frentes.
#
# Uma reformulação possível de D seria: “Como o lucro bruto observado varia entre os canais de divulgação?” Essa pergunta poderia ser investigada como subpergunta, sem atribuir as diferenças ao efeito do canal.
#
# Se a dupla marcar “Sim” no primeiro critério de D apenas porque localizou as duas colunas, peça que diferencie **encontrar as variáveis mencionadas** de **dispor de todas as informações necessárias para responder à pergunta como ela foi formulada**. A segunda condição é a que está sendo avaliada.
#
# Na correção, solicite uma justificativa com informações concretas do conjunto. Identificar a alternativa A, sem explicar sua adequação para orientar este projeto, não demonstra a aplicação dos quatro critérios.

# %% [markdown]
# ### Registro 4 — escolha e justificativa
#
# **Pergunta adequada para orientar este projeto:** **A**.
#
# Exemplo de justificativa:
#
# > A pergunta A é adequada para orientar este projeto porque todas as informações necessárias para construir a resposta exploratória podem ser extraídas do conjunto fornecido. Por exemplo, `entradas` e `cupons_emitidos` permitem examinar movimento e compras; `investimento_divulgacao`, `horas_equipe`, `espera_media_min`, `disponibilidade_produtos_pct` e `desconto_campanha_pct` permitem investigar condições associadas ao desempenho; e `receita_liquida` e `lucro_bruto` permitem examinar o resultado comercial. A pergunta não exige que a AED conclua uma relação de causa e efeito. Ela é suficiente para atender ao problema de recomendar uma prioridade inicial à rede e é ampla o suficiente para orientar e justificar a seleção de variáveis, a escolha de medidas e gráficos, as comparações, o exame de relações e a integração das evidências nas próximas etapas.
#
# Aceite formulações equivalentes que expliquem os quatro critérios e citem variáveis pertinentes; não exija a reprodução de toda a lista do exemplo.
#
# A justificativa deve distinguir uma **prioridade inicial apoiada em evidências** de uma garantia de melhoria. Nesta aula, avalie a escolha da pergunta adequada para orientar este projeto; a indicação da ação comercial será construída nas etapas seguintes.

# %%
# Conferência do professor — estrutura e pontos de atenção do conjunto
assert len(dados) == 5001
assert dados.shape[1] == 13
assert dados.duplicated().sum() == 1

dados_conf = dados.drop_duplicates().copy()
assert len(dados_conf) == 5000
assert dados_conf["espera_media_min"].isna().sum() == 24
assert dados_conf["espera_media_min"].notna().sum() == 4976

print("Conferência concluída:")
print("- 5.001 linhas no arquivo")
print("- 1 cópia duplicada")
print("- 5.000 registros únicos")
print("- 24 valores ausentes em espera_media_min")

# %% [markdown]
# ## Expectativa de entrega
#
# Um notebook preenchido e salvo por dupla, contendo:
#
# - leitura da estrutura do conjunto;
# - interpretação dos pontos de atenção;
# - comparação das quatro perguntas candidatas;
# - pergunta principal selecionada e justificativa;
# - uma expectativa inicial para as próximas etapas do projeto.

# %% [markdown]
# ## Critérios para avaliação
#
# Utilize os níveis: **A — Atendeu    AP — Atendeu parcialmente    NA — Não atendeu**
#
# | Critério | A | AP | NA |
# |---|---|---|---|
# | Reconhece o que cada registro representa e identifica informações disponíveis. | | | |
# | Interpreta adequadamente duplicação e valores ausentes. | | | |
# | Examina as perguntas aplicando os quatro critérios de adequação a este projeto. | | | |
# | Escolhe uma pergunta adequada para orientar este projeto e justifica os quatro critérios com informações do conjunto. | | | |
# | Registra uma expectativa coerente e aberta à verificação pelas evidências. | | | |

# %% [markdown]
# ## Análise pedagógica
#
# A atividade verifica o objetivo da aula porque a dupla precisa **examinar** o conjunto e **escolher** uma pergunta adequada para orientar este projeto aplicando os quatro critérios — operações compatíveis com o nível **Aplicar** do dicionário vigente.
#
# A execução técnica permanece reduzida. As células de código carregam o conjunto, mostram os pontos de atenção e preparam os 5.000 registros únicos; o trabalho cognitivo está na interpretação e na justificativa.
#
# A revisão dos conhecimentos anteriores é distribuída entre dois espaços:
#
# - **Relembre:** conceitos estruturantes que organizam a investigação;
# - **notebook:** retomadas implícitas acionadas pela prática, como tipos de dados, registro/variável, duplicação e valores ausentes.
#
# Isso evita repetir o bimestre em uma revisão expositiva e preserva carga cognitiva para a decisão central da A1.
#
# **Limite da atividade:** o conjunto é didático e simulado. As conclusões posteriores descrevem a estrutura desse conjunto; não constituem evidência sobre o varejo brasileiro ou sobre empresas reais.
