# %% [markdown]
# # Aula 3 — Prática de operações vetoriais aplicadas a dados
#
# Componente: Matemática e Estatística para Ciência de Dados
# Unidade: Matemática Aplicada
# Semana 1: Vetores e Matrizes
# Aula 3: Prática de operações vetoriais aplicadas a dados
#
# Neste notebook, você vai usar dados reais para calcular vetores, organizar uma matriz de resultados e escrever uma recomendação técnica curta para uma campanha de uso seguro da internet.

# %% [markdown]
# ## Objetivos da prática
#
# - Aplicar soma, subtração e multiplicação por escalar com vetores.
# - Manter a ordem dos dados durante os cálculos vetoriais.
# - Organizar resultados em uma matriz de resultados.
# - Interpretar resultados para justificar uma recomendação.
# - Usar dados reais para apoiar uma decisão em contexto aplicado.

# %% [markdown]
# ## Contexto da atividade
#
# A equipe júnior de Ciência de Dados está apoiando uma campanha escolar de orientação sobre uso seguro da internet.
#
# A equipe trabalha com dados reais sobre a frequência de uso de plataformas digitais por adolescentes e precisa usar operações vetoriais para transformar esses dados em critérios de decisão.
#
# A campanha terá duas frentes:
#
# - Alerta rápido: recado curto para chegar aos estudantes com mais frequência.
# - Reforço semanal: conteúdo para circular ao longo da semana.
#
# Produto esperado:
#
# - matriz de resultados;
# - recomendação técnica curta para a coordenação da escola.

# %% [markdown]
# ## Parte 1 — Preparação dos dados
#
# A ordem das plataformas deve ser mantida em todos os vetores:
#
# [Facebook; Instagram; X/Twitter; TikTok; WhatsApp; YouTube; Discord]
#
# Cada posição do vetor representa uma plataforma digital. Se a ordem mudar, os cálculos passam a comparar dados de plataformas diferentes.

# %%
plataformas = [
    "Facebook",
    "Instagram",
    "X/Twitter",
    "TikTok",
    "WhatsApp",
    "YouTube",
    "Discord"
]

# A = várias vezes ao dia
A = [20, 63, 6, 47, 78, 38, 4]

# B = todos ou quase todos os dias
B = [8, 19, 3, 12, 13, 22, 3]

# S = pelo menos uma vez por semana
S = [12, 8, 7, 12, 4, 19, 3]

# N = nunca ou quase nunca
N = [52, 9, 77, 25, 4, 17, 79]

plataformas, A, B, S, N

# %% [markdown]
# ### Conferência inicial
#
# Antes de calcular, confira:
#
# 1. Todos os vetores têm 7 valores?
# 2. Todos seguem a mesma ordem das plataformas?
# 3. Cada posição representa a mesma plataforma em todos os vetores?

# %%
# Execute esta célula para conferir o tamanho dos vetores.
# Todos devem ter o mesmo tamanho.

tamanhos = {
    "plataformas": len(plataformas),
    "A": len(A),
    "B": len(B),
    "S": len(S),
    "N": len(N)
}

tamanhos

# %% [markdown]
# ## Parte 2 — Cálculos com vetores
#
# Critérios da prática:
#
# D = A + B
# D representa uso frequente.
#
# W = D + S
# W representa uso semanal ou mais.
#
# R = W − N
# R representa a pontuação de reforço semanal.
#
# E = 2D + S
# E representa a pontuação de alerta rápido.
#
# Observação importante:
#
# - R é diferença entre percentuais, por isso deve ser lido em pontos percentuais, p.p.
# - E é uma pontuação criada para a atividade, não é percentual.

# %% [markdown]
# ### Passo 1 — Calcule o vetor D
#
# D = A + B
#
# Esse vetor representa o uso frequente das plataformas.

# %%
# Complete o cálculo do vetor D.
# Dica: some os valores de A e B posição por posição.

D = [        ]

D

# %% [markdown]
# ### Escreva sua interpretação do vetor D
#
# O que o vetor D representa na atividade?

# %% [markdown]
# Resposta:

# %% [markdown]
# ### Passo 2 — Calcule o vetor W
#
# W = D + S
#
# Esse vetor representa o uso semanal ou mais das plataformas.

# %%
# Complete o cálculo do vetor W.
# Dica: some os valores de D e S posição por posição.

W = [        ]

W

# %% [markdown]
# ### Escreva sua interpretação do vetor W
#
# O que o vetor W acrescenta à análise?

# %% [markdown]
# Resposta:

# %% [markdown]
# ### Passo 3 — Calcule o vetor R
#
# R = W − N
#
# Esse vetor representa a pontuação de reforço semanal.
#
# Lembre-se: como R é diferença entre percentuais, os resultados devem ser lidos em p.p.

# %%
# Complete o cálculo do vetor R.
# Dica: subtraia os valores de N dos valores de W, posição por posição.

R = [        ]

R

# %% [markdown]
# ### Escreva sua interpretação do vetor R
#
# O que significa um valor negativo em R?

# %% [markdown]
# Resposta:

# %% [markdown]
# ### Passo 4 — Calcule o vetor E
#
# E = 2D + S
#
# Esse vetor representa a pontuação de alerta rápido.
#
# Lembre-se: E é uma pontuação criada para esta atividade. Não escreva os resultados como percentuais.

# %%
# Complete o cálculo do vetor E.
# Dica: multiplique cada valor de D por 2 e depois some o valor correspondente de S.

E = [        ]

E

# %% [markdown]
# ### Escreva sua interpretação do vetor E
#
# Por que os resultados de E não devem ser lidos como percentuais?

# %% [markdown]
# Resposta:

# %% [markdown]
# ## Parte 3 — matriz de resultados
#
# Agora, organize os resultados em uma matriz de resultados.
#
# A ordem das linhas segue a lista `plataformas`.
#
# Colunas da matriz:
#
# - D: uso frequente
# - W: uso semanal ou mais
# - R: reforço semanal
# - E: alerta rápido

# %%
# Depois de calcular D, W, R e E, execute esta célula
# para montar a matriz numérica de resultados.

matriz_resultados = [
    [D[i], W[i], R[i], E[i]]
    for i in range(len(plataformas))
]

matriz_resultados

# %% [markdown]
# ### Conferência da matriz
#
# Antes de responder às perguntas finais, confira:
#
# 1. A ordem das plataformas foi mantida?
# 2. Cada valor calculado está na linha da plataforma correta?
# 3. Os resultados de R foram registrados em p.p.?
# 4. Os resultados de E foram registrados como pontos?

# %% [markdown]
# ## Parte 4 — Análise e decisão
#
# Use a matriz de resultados para responder.

# %% [markdown]
# ### Pergunta 1
#
# Quais dois canais devem ser priorizados no alerta rápido?
#
# Critério: maiores valores de E.
#
# Resposta:

# %% [markdown]
# ### Pergunta 2
#
# Qual canal deve ser usado como reforço semanal sem repetir os dois canais principais?
#
# Critério: maior valor de R entre as plataformas que não foram escolhidas para o alerta rápido.
#
# Resposta:

# %% [markdown]
# ### Pergunta 3
#
# Quais plataformas exigem cuidado antes de serem escolhidas como canais principais?
#
# Critério: R negativo.
#
# Resposta:

# %% [markdown]
# ### Pergunta 4 — Recomendação final
#
# Escreva uma recomendação final de 3 a 4 linhas para a coordenação da escola.
#
# Sua recomendação deve citar:
#
# - os dois canais indicados para o alerta rápido;
# - o canal indicado para o reforço semanal;
# - pelo menos um dado calculado para justificar a escolha;
# - as plataformas que exigem cuidado antes de serem priorizadas.
#
# Resposta:

# %% [markdown]
# ## Registro final
#
# Responda no notebook ou no espaço indicado pelo professor.
#
# 1. Qual foi o vetor D calculado?
#
# Resposta:
#
# 2. O que o vetor D representa na atividade?
#
# Resposta:
#
# 3. Qual foi o vetor W calculado?
#
# Resposta:
#
# 4. O que o vetor W representa na atividade?
#
# Resposta:
#
# 5. Qual foi o vetor R calculado?
#
# Resposta:
#
# 6. Por que os resultados de R devem ser lidos em p.p.?
#
# Resposta:
#
# 7. Qual foi o vetor E calculado?
#
# Resposta:
#
# 8. Por que os resultados de E não devem ser lidos como percentuais?
#
# Resposta:
#
# 9. Quais dois canais devem ser priorizados no alerta rápido?
#
# Resposta:
#
# 10. Qual canal deve ser usado como reforço semanal sem repetir os canais principais?
#
# Resposta:
#
# 11. Quais plataformas exigem cuidado antes de serem escolhidas como canais principais?
#
# Resposta:
#
# 12. Escreva a recomendação final para a coordenação da escola.
#
# Resposta:

# %% [markdown]
# ## Fechamento esperado
#
# Ao final da prática, você deverá ter:
#
# 1. conferido a ordem das plataformas;
# 2. calculado o vetor D;
# 3. calculado o vetor W;
# 4. calculado o vetor R;
# 5. calculado o vetor E;
# 6. organizado uma matriz de resultados;
# 7. identificado canais para alerta rápido e reforço semanal;
# 8. escrito uma recomendação técnica curta com base nos dados calculados.
