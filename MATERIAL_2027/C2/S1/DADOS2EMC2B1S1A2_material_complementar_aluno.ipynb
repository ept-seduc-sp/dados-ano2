# %% [markdown]
# <h1 style="text-align:center;">TÉCNICO EM CIÊNCIA DE DADOS</h1>
# <h1 style="text-align:center;">Material Complementar</h1>
# <br>
# <strong>Componente:</strong> Matemática e Estatística para Ciência de Dados<br>
# <strong>Unidade Curricular:</strong> Vetores e Matrizes<br>
# <strong>Tema da Semana:</strong> Operações com vetores<br>
# <strong>Semana 1</strong><br>
# <strong>Aula 2:</strong> Operações com vetores

# %% [markdown]
# <h2 style="text-align:center;">Escolhendo canais para uma campanha</h2>

# %% [markdown]
# ## Orientações
# Use o relatório projetado para completar os vetores na ordem indicada. Depois, execute os cálculos de `F` e `P` e compare as saídas com os registros feitos pela dupla.

# %% [markdown]
# ### Etapa 1 — Montar os vetores A, B e C
# Ordem das plataformas: Facebook, Instagram, X/Twitter, TikTok, WhatsApp, YouTube, Discord.

# %%
A = [
    # complete com os valores de "Várias vezes ao dia"
]

B = [
    # complete com os valores de "Todos os dias ou quase todos os dias"
]

C = [
    # complete com os valores de "Nunca ou quase nunca"
]

# %% [markdown]
# ### Etapa 2 — Calcular F e P
# `F` representa o uso frequente. `P` representa a pontuação de alcance definida para esta atividade.

# %%
F = [A[i] + B[i] for i in range(len(A))]
P = [F[i] - C[i] for i in range(len(F))]

print("F =", F)
print("P =", P)

# %% [markdown]
# ### Etapa 3 — Conferir a correspondência com as plataformas
# Execute a célula para visualizar cada plataforma ao lado de sua pontuação `P`.

# %%
plataformas = ["Facebook", "Instagram", "X/Twitter", "TikTok", "WhatsApp", "YouTube", "Discord"]

for i in range(len(plataformas)):
    print(plataformas[i], "→", P[i])

# %% [markdown]
# ### Etapa 4 — Interpretar
# Use as saídas para identificar os dois maiores valores de `P`, diferenciar pontuações positivas e negativas e justificar a recomendação de duas plataformas no material complementar.
