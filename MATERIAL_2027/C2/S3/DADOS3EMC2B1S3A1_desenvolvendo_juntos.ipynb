# %% [markdown]
# <h1 style="text-align:center;">TÉCNICO EM CIÊNCIA DE DADOS</h1>
#
# <h1 style="text-align:center;">Prática Guiada - Desenvolvendo Juntos</h1>
#
# **Componente:** Matemática e Estatística para Ciência de Dados
# **Unidade Curricular:** Estatística Aplicada
# **Tema da Semana:** Tipos de Dados e Estatística Básica
# **Semana 3**
# **Aula 1:** Introdução à estatística e aos tipos de dados
#
# <h2 style="text-align:center;">Entendendo o que um dado representa</h2>

# %% [markdown]
# ## Contexto
#
# A equipe júnior de Ciência de Dados está trabalhando com informações da **Pesquisa de Satisfação e Qualidade Percebida 2025**, da Anatel.
#
# Nesta Prática Guiada, acompanhe o professor e execute as células na sequência. O objetivo é observar **o que cada informação representa** antes de classificá-la.
#
# **Fonte:** AGÊNCIA NACIONAL DE TELECOMUNICAÇÕES (ANATEL). *Pesquisa de Satisfação e Qualidade Percebida 2025*. Brasília, DF: Anatel, 2026.
# Dados brutos e resultados consolidados: https://www.anatel.gov.br/dadosabertos/paineis_de_dados/consumidor/pesquisa_de_satisfacao.zip
# Acesso em: 17 ago. 2026.

# %% [markdown]
# ## Passo 1 — Faça uma previsão
#
# Antes de executar o código, observe as duas informações:
#
# - **Internet fixa**
# - **18.996**
#
# Converse com o professor: **o que cada uma delas informa?**

# %% [markdown]
# ## Passo 2 — Execute a célula
#
# A célula abaixo armazena e exibe as duas informações.
#
# **Código Python**

# %%
tipo_servico = "Internet fixa"
numero_entrevistas = 18996

print("Tipo de serviço:", tipo_servico)
print("Número de entrevistas:", numero_entrevistas)

# %% [markdown]
# ## Passo 3 — Compare
#
# Com o professor, compare a saída:
#
# - **Internet fixa** indica um **tipo de serviço**.
# - **18.996** indica uma **quantidade de entrevistas**.
#
# **Essas duas informações representam a mesma coisa? Por quê?**
#
# Registre sua resposta no roteiro em Word.

# %% [markdown]
# ## Passo 4 — Registre a regra provisória
#
# No roteiro em Word, complete com suas palavras:
#
# > **Antes de classificar um dado, precisamos entender ________________________________.**
#
# Não é necessário usar ainda nomes técnicos para os grupos.
