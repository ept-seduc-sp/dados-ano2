# %% [markdown]
# <h1 style="text-align: center;">TÉCNICO EM CIÊNCIA DE DADOS</h1>
# <h1 style="text-align: center;">Colocando em Prática</h1>
# <br>
# <strong>Componente:</strong> Matemática e Estatística para Ciência de Dados<br>
# <strong>Unidade Curricular:</strong> Estatística Aplicada — U2<br>
# <strong>Tema da Semana:</strong> Tendência Central<br>
# <strong>Semana 4</strong><br>
# <strong>Aula 1:</strong> Média, mediana e moda

# %% [markdown]
# ## Analisando produtos nos anúncios
#
# A equipe de dados da **Olist** está analisando como os produtos de um recorte da base são apresentados nos anúncios. O objetivo é resumir a **quantidade de fotos associadas aos produtos analisados** e preparar uma síntese para a equipe.

# %% [markdown]
# ## Dados do recorte
#
# O recorte contém 12 registros consecutivos do arquivo consultado. Os valores representam a **quantidade de fotos associadas a cada produto**.

# %%
fotos = [4, 4, 2, 3, 3, 2, 2, 1, 5, 2, 1, 4]
print("Quantidade de fotos por produto:", fotos)

# %% [markdown]
# ## 1. Calcule a média
#
# Use os comandos que você já utilizou no **Desenvolvendo Juntos**.
#
# - obtenha a soma dos valores;
# - verifique a quantidade de registros;
# - calcule a média;
# - registre e interprete o resultado no documento da atividade.

# %%
# Escreva aqui o código para calcular a média.
# Use as funções sum() e len() já trabalhadas.

# %% [markdown]
# ## 2. Determine a mediana
#
# - organize os valores em ordem crescente;
# - localize as duas posições centrais;
# - calcule a mediana;
# - registre e interprete o resultado no documento da atividade.

# %%
# Escreva aqui o código para ordenar os dados e calcular a mediana.
# Use sorted() e os índices da lista, como no Desenvolvendo Juntos.

# %% [markdown]
# ## 3. Identifique a moda
#
# - verifique quantas vezes os valores 1, 2, 3, 4 e 5 aparecem;
# - compare as frequências;
# - identifique o valor com maior frequência;
# - registre e interprete a moda no documento da atividade.

# %%
# Escreva aqui o código para comparar as frequências.
# Use o método .count() já trabalhado.

# %% [markdown]
# ## 4. Prepare a síntese
#
# Com os três resultados em mãos, complete o **Registro da análise** no documento da atividade e escreva uma conclusão curta para a equipe.
#
# Sua conclusão deve:
# - apresentar o que média, mediana e moda mostram neste recorte;
# - destacar qual quantidade de fotos aparece com maior frequência;
# - usar os resultados obtidos como evidência.

# %% [markdown]
# ---
# ### Fonte e rastreabilidade
#
# O recorte reúne **12 registros consecutivos** da variável `product_photos_qty`, correspondentes às **linhas 43 a 54 do arquivo consultado**, preservando a ordem original. Nenhum valor foi criado ou alterado.
#
# Conferência direta: https://raw.githubusercontent.com/HarshGupta-DS/E-Commerce_Analysis/refs/heads/main/olist_products_dataset.csv
