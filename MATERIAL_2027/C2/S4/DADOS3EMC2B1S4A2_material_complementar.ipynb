# %% [markdown]
# # Material Complementar — Aula 2
# **Componente:** Matemática e Estatística para Ciência de Dados
# **Tema da semana:** Tendência Central
# **Aula 2:** Interpretação de medidas estatísticas
# **Semana 4**
#
# O Python será usado para processar os dados. Registre interpretações e conclusões no documento da atividade.

# %% [markdown]
# ## Parte 1 — Teste sua decisão
#
# A equipe analisa os pesos, em gramas, de 9 produtos:
#
# **225 | 1.000 | 154 | 371 | 625 | 200 | 18.350 | 900 | 400**
#
# Use procedimentos já conhecidos para calcular a média, ordenar os dados e determinar a mediana.

# %%
pesos_1 = [225, 1000, 154, 371, 625, 200, 18350, 900, 400]
pesos_1

# %%
# Calcule a soma, a quantidade de registros e a média.
# Escreva seu código abaixo.

# %%
# Organize os dados em ordem crescente e determine a mediana.
# Escreva seu código abaixo.

# %% [markdown]
# ### Compare os resultados
#
# Registre no documento:
# - o que chama atenção na comparação entre média e mediana;
# - qual valor do conjunto parece estar relacionado à diferença observada.

# %% [markdown]
# ## Parte 2 — Novo recorte
#
# A equipe de logística recebe os pesos de outros 10 produtos:
#
# **600 | 1.100 | 7.150 | 250 | 600 | 200 | 800 | 400 | 900 | 1.700**
#
# Calcule média e mediana, identifique o valor que mais se distancia dos demais e investigue o efeito dele sobre as duas medidas.

# %%
pesos_2 = [600, 1100, 7150, 250, 600, 200, 800, 400, 900, 1700]
pesos_2

# %%
# Calcule a média do conjunto.
# Escreva seu código abaixo.

# %%
# Ordene os dados e determine a mediana.
# Escreva seu código abaixo.

# %% [markdown]
# ### Investigue o valor que mais se distancia dos demais
#
# Depois de identificá-lo, crie uma nova lista sem esse valor **apenas para investigar seu efeito**.
#
# > A retirada temporária não significa que o registro deva ser excluído da base.

# %%
# Crie uma nova lista com os 9 pesos restantes.
# Depois, recalcule média e mediana.
# Escreva seu código abaixo.

# %% [markdown]
# ### Compare e decida
#
# Compare:
# - média com todos os produtos × média sem o valor investigado;
# - mediana com todos os produtos × mediana sem o valor investigado.
#
# Depois, registre no documento sua resposta para a demanda da equipe de logística.
