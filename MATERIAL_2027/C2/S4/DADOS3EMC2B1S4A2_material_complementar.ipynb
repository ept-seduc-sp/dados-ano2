# %% [markdown]
# # Material Complementar — Aula 2
#
# **Componente:** Matemática e Estatística para Ciência de Dados
# **Tema da semana:** Tendência Central
# **Semana 4**
# **Aula 2:** Interpretação de medidas estatísticas
#
# O Python será usado para processar os dados. Registre interpretações, decisões e conclusões no documento da atividade:
# `DADOS3EMC2B1S4A2_material_complementar.docx`

# %% [markdown]
# ## Parte 1 — O número conta toda a história?
#
# ### Teste sua decisão
#
# Você integra a equipe de dados da Olist. Antes de uma reunião, o gestor recebe a informação de que o peso médio dos produtos deste recorte é de **2.469,44 g**.
#
# **Dados do recorte:**
# **225 | 1.000 | 154 | 371 | 625 | 200 | 18.350 | 900 | 400 g**
#
# Use o Python para:
# 1. calcular a média dos 9 pesos;
# 2. organizar os dados em ordem crescente;
# 3. determinar a mediana;
# 4. comparar os dois resultados.
#
# Registre no DOCX o que chama sua atenção na comparação.

# %%
pesos_1 = [225, 1000, 154, 371, 625, 200, 18350, 900, 400]
pesos_1

# %%
# Calcule a soma, a quantidade de registros e a média.
# Escreva seu código abaixo.

# %%
# Organize os dados em ordem crescente e determine a mediana.
# Escreva seu código abaixo.

# %% [markdown]
# ### Compare os resultados
#
# No DOCX, registre:
# - a média encontrada;
# - a mediana encontrada;
# - o que chama sua atenção na comparação entre os dois resultados.

# %% [markdown]
# ## Parte 2 — Volte à sua decisão
#
# Esta etapa **não exige novo cálculo no Python**.
#
# Depois de analisar o efeito do valor que mais se distancia dos demais, volte ao DOCX e revise sua decisão inicial:
#
# **Você manteria a média de 2.469,44 g como principal valor para resumir esse conjunto ao gestor, considerando que a informação deve representar o peso típico dos produtos analisados?**
#
# Justifique sua decisão usando os resultados da análise.

# %% [markdown]
# ## Parte 3 — Analise um novo recorte
#
# A equipe de logística recebe os pesos de outros 10 produtos. Para planejar a carga de lotes com perfil semelhante, a equipe precisa considerar o peso de **todos os produtos**, inclusive os mais pesados.
#
# **Dados do recorte:**
# **600 | 1.100 | 7.150 | 250 | 600 | 200 | 800 | 400 | 900 | 1.700 g**
#
# ### Sua missão
#
# 1. Calcule a média e a mediana do conjunto.
# 2. Identifique o valor que mais se distancia dos demais.
# 3. Recalcule média e mediana sem esse valor, apenas para investigar seu efeito.
# 4. Compare os resultados obtidos nas duas situações.
# 5. Considerando a necessidade da equipe de logística, indique no DOCX qual medida deve orientar a estimativa do peso médio por produto e justifique com os dados.

# %%
pesos_2 = [600, 1100, 7150, 250, 600, 200, 800, 400, 900, 1700]
pesos_2

# %%
# Calcule a média do conjunto.
# Escreva seu código abaixo.

# %%
# Organize os dados em ordem crescente e determine a mediana.
# Escreva seu código abaixo.

# %% [markdown]
# ### Investigue o valor que mais se distancia dos demais
#
# Depois de identificá-lo, crie uma nova lista sem esse valor **apenas para investigar seu efeito**.
#
# > A retirada temporária não significa que o registro deva ser excluído da base.

# %%
# Crie uma nova lista com os 9 pesos restantes.
# Depois, recalcule média e mediana.
# Escreva seu código abaixo.

# %% [markdown]
# ### Registro da análise
#
# Compare:
# - média com os 10 produtos × média sem o valor investigado;
# - mediana com os 10 produtos × mediana sem o valor investigado.
#
# Registre os resultados na tabela correspondente do DOCX.

# %% [markdown]
# ### Conclusão para a equipe
#
# No DOCX, em até três frases:
# - indique a medida escolhida para a finalidade proposta;
# - apresente as evidências numéricas que justificam sua decisão.

# %% [markdown]
# ### Fonte e rastreabilidade dos recortes
#
# Os dois conjuntos foram extraídos da variável `product_weight_g` do arquivo `olist_products_dataset.csv`, integrante da base pública **Brazilian E-Commerce Public Dataset by Olist**. O primeiro caso utiliza os 9 primeiros registros consultados; o segundo utiliza os 10 registros seguintes, preservando a ordem original.
#
# Referência principal: OLIST. *Brazilian E-Commerce Public Dataset by Olist*. Kaggle.
# https://www.kaggle.com/datasets/olistbr/brazilian-ecommerce
