# %% [markdown]
# <h1 style="text-align:center;">TÉCNICO EM CIÊNCIA DE DADOS</h1>
#
# <h1 style="text-align:center;">Material Complementar</h1>
#
# **Componente:** Matemática e Estatística para Ciência de Dados
# **Unidade Curricular:** Matemática Aplicada
# **Tema da Semana:** Operações Matriciais
# **Semana 2**
# **Aula 1:** Introdução às matrizes

# %% [markdown]
# <h2 style="text-align:center;">Guia digital sobre o uso da IA generativa</h2>

# %% [markdown]
# ## Como usar este notebook
#
# Este arquivo é a parte computacional da atividade.
#
# - Leia o enunciado e registre as respostas no **DOCX**.
# - Execute aqui somente os procedimentos indicados.
# - Ao terminar cada etapa, volte ao **DOCX** para registrar o resultado.
# - A nota de análise final deve ser escrita no **DOCX**.

# %% [markdown]
# ## Etapa 1 — Construir e visualizar a matriz B
#
# No DOCX, você já selecionou as duas faixas etárias solicitadas.
#
# Complete abaixo a matriz **B** com os quatro percentuais de cada faixa etária, mantendo a mesma ordem das colunas da tabela.
#
# **Código Python**

# %%
finalidades = [
    "Estudar ou fazer pesquisas escolares",
    "Procurar informações",
    "Criar textos, imagens, vídeos ou códigos",
    "Conversar sobre problemas ou emoções"
]

B = [
    [],  # complete com os 4 valores da primeira faixa etária selecionada
    []   # complete com os 4 valores da segunda faixa etária selecionada
]

if len(B) == 2 and all(len(linha) == 4 for linha in B):
    print("Matriz B:")
    for linha in B:
        print(linha)
else:
    print("Complete B com duas linhas e quatro valores em cada linha.")

# %% [markdown]
# **Volte ao DOCX.** Registre a matriz B e explique o que representam suas linhas e suas colunas.

# %% [markdown]
# ## Etapa 2 — Conferir a ordem da matriz
#
# Execute a célula para conferir o número de linhas, o número de colunas e a ordem da matriz.
#
# **Código Python**

# %%
if len(B) == 2 and all(len(linha) == 4 for linha in B):
    numero_linhas = len(B)
    numero_colunas = len(B[0])
    print("Número de linhas:", numero_linhas)
    print("Número de colunas:", numero_colunas)
    print("Ordem da matriz:", numero_linhas, "x", numero_colunas)
else:
    print("Complete corretamente a matriz B antes de conferir sua ordem.")

# %% [markdown]
# **Volte ao DOCX.** Registre a ordem da matriz B.

# %% [markdown]
# ## Etapa 3 — Comparar as quatro finalidades
#
# Execute a célula para visualizar, lado a lado, os percentuais das quatro finalidades.
#
# Ainda não há uma resposta pronta: observe os quatro pares e decida quais **duas finalidades mais se destacam nas duas faixas etárias**.
#
# **Código Python**

# %%
if len(B) == 2 and all(len(linha) == 4 for linha in B):
    for j in range(4):
        print(f"Coluna {j+1} - {finalidades[j]}")
        print("  Faixa etária 1:", B[0][j], "%")
        print("  Faixa etária 2:", B[1][j], "%")
else:
    print("Complete corretamente a matriz B antes de comparar os percentuais.")

# %% [markdown]
# **Volte ao DOCX.** Registre as duas finalidades escolhidas.

# %% [markdown]
# ## Etapa 4 — Consultar as entradas das duas finalidades escolhidas
#
# No DOCX, observe em quais colunas estão as duas finalidades escolhidas.
#
# Digite abaixo os números dessas colunas, de **1 a 4**. O código fará a conversão para os índices do Python e mostrará as quatro entradas correspondentes.
#
# **Código Python**

# %%
coluna_1 = None  # substitua None pelo número da primeira coluna escolhida: 1, 2, 3 ou 4
coluna_2 = None  # substitua None pelo número da segunda coluna escolhida: 1, 2, 3 ou 4

if len(B) == 2 and all(len(linha) == 4 for linha in B) and coluna_1 in [1,2,3,4] and coluna_2 in [1,2,3,4]:
    j1 = coluna_1 - 1
    j2 = coluna_2 - 1

    print("Finalidade 1:", finalidades[j1])
    print(f"b(1,{coluna_1}) -> B[0][{j1}] =", B[0][j1])
    print(f"b(2,{coluna_1}) -> B[1][{j1}] =", B[1][j1])
    print()

    print("Finalidade 2:", finalidades[j2])
    print(f"b(1,{coluna_2}) -> B[0][{j2}] =", B[0][j2])
    print(f"b(2,{coluna_2}) -> B[1][{j2}] =", B[1][j2])
else:
    print("Complete B e informe coluna_1 e coluna_2 com números de 1 a 4.")

# %% [markdown]
# **Volte ao DOCX.** Registre as entradas consultadas e escreva a nota de análise.
#
# O notebook termina aqui: a interpretação e a comunicação da recomendação pertencem ao **DOCX**.
