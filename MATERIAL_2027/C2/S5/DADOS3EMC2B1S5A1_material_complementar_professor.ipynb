# %% [markdown]
# <h1 style="text-align: center;">Técnico em Ciência de Dados</h1>
#
# ## Material Complementar
#
# **Componente:** Matemática e Estatística para Ciência de Dados
# **Unidade Curricular:** Matemática Aplicada
# **Tema da Semana:** Modelos Lineares
# **Semana 5**
# **Aula 1:** Equação da reta
#
# ## Novas previsões com Python
#
# **Modelo utilizado:** `V = 6,55 + 4,80d`
#
# - `V`: valor estimado da corrida;
# - `d`: distância percorrida, em km.
#
# > **Recorte didático:** o modelo considera apenas a bandeirada de R$ 6,55 e a tarifa quilométrica de R$ 4,80 da Bandeira 1. Não representa todas as condições de uma corrida real.

# %% [markdown]
# ## Etapa 1 — Execute as previsões definidas
#
# As distâncias foram organizadas em quatro pares. Em cada par, a segunda distância é exatamente **1 km maior** que a primeira.
#
# Execute a célula e registre os valores no documento complementar.

# %%
bandeirada = 6.55
tarifa_km = 4.80

distancias = [8, 9, 12, 13, 17, 18, 23, 24]

for d in distancias:
    valor = bandeirada + tarifa_km * d
    print(f"{d} km -> R$ {valor:.2f}".replace(".", ","))
# Out:
# 8 km -> R$ 44,95
# 9 km -> R$ 49,75
# 12 km -> R$ 64,15
# 13 km -> R$ 68,95
# 17 km -> R$ 88,15
# 18 km -> R$ 92,95
# 23 km -> R$ 116,95
# 24 km -> R$ 121,75

# %% [markdown]
# ## Etapa 2 — Compare os pares
#
# No documento complementar, compare: **8 e 9 km**, **12 e 13 km**, **17 e 18 km**, **23 e 24 km**.
#
# Antes de executar a célula seguinte, registre sua conclusão sobre o que acontece com o valor estimado quando a distância aumenta **1 km**.

# %%
pares = [(8, 9), (12, 13), (17, 18), (23, 24)]

for d1, d2 in pares:
    v1 = bandeirada + tarifa_km * d1
    v2 = bandeirada + tarifa_km * d2
    diferenca = v2 - v1
    print(f"{d1} -> {d2} km: diferença = R$ {diferenca:.2f}".replace(".", ","))
# Out:
# 8 -> 9 km: diferença = R$ 4,80
# 12 -> 13 km: diferença = R$ 4,80
# 17 -> 18 km: diferença = R$ 4,80
# 23 -> 24 km: diferença = R$ 4,80

# %% [markdown]
# ## Interpretação esperada
#
# Em todos os pares, o aumento de **1 km** produz um acréscimo de **R$ 4,80** no valor estimado. Esse valor corresponde ao **coeficiente angular** da equação trabalhada na aula.
#
# ### Saídas esperadas
#
# | Distância | Valor estimado |
# |---:|---:|
# | 8 km | R$ 44,95 |
# | 9 km | R$ 49,75 |
# | 12 km | R$ 64,15 |
# | 13 km | R$ 68,95 |
# | 17 km | R$ 88,15 |
# | 18 km | R$ 92,95 |
# | 23 km | R$ 116,95 |
# | 24 km | R$ 121,75 |
#
# **Mediação:** se os estudantes confundirem o valor inicial de R$ 6,55 com a variação por quilômetro, retome a diferença entre intercepto e coeficiente angular. O foco é interpretar a saída, não introduzir novos recursos de Python.

# %% [markdown]
# ## Fonte dos valores utilizados
#
# PREFEITURA DE SÃO PAULO. Portaria SMT.GAB nº 41, de 31 de julho de 2025. Disponível em: https://legislacao.prefeitura.sp.gov.br/portaria-secretaria-municipal-de-mobilidade-urbana-e-transporte-smt-41-de-31-de-julho-de-2025. Acesso em: 31 ago. 2026.
