# %% [markdown]
# <h1 style="text-align: center;">TÉCNICO EM CIÊNCIA DE DADOS</h1>
# <h1 style="text-align: center;">Filtragem e agrupamento de dados no PySpark</h1>
# <br>
#
# **Componente:** Fundamentos de Ambientes e Arquitetura de Dados
# <br>
# **Unidade Curricular:** Introdução ao PySpark e Processamento Distribuído
# <br>
# **Tema da Semana:** Filtragem e Agrupamento
# <br>
# **Semana 19 - Aula 3**
# <br>
# **Atividade:** Análise de vendas por região e setor

# %% [markdown]
# ## Objetivo prático
#
# Aplicar os conceitos estudados na semana em uma atividade de análise de dados no PySpark.
#
# Ao longo da atividade, você deverá:
#
# 1. Ler um arquivo CSV com `header` e `inferSchema`.
# 2. Verificar o schema do DataFrame.
# 3. Aplicar filtros simples com `filter()`.
# 4. Combinar condições lógicas em um filtro.
# 5. Utilizar `isin()` para selecionar múltiplas regiões.
# 6. Agrupar dados com `groupBy()`.
# 7. Calcular métricas com `count()`, `sum()` e `avg()`.
# 8. Utilizar `agg()` para obter mais de uma métrica em uma única operação.

# %% [markdown]
# ## Lista de materiais
#
# - Ambiente com PySpark configurado.
# - Este notebook.
# - Arquivo auxiliar no mesmo diretório: `DADOSANO2C6B3S19A3_auxiliar.csv`.

# %% [markdown]
# ## Orientações
#
# - Execute as células na ordem.
# - Complete as células com `# TODO`.
# - Observe como os resultados mudam após cada filtro.
# - Compare as diferentes saídas dos agrupamentos e agregações.
# - Ao final, o notebook deve mostrar os resultados pedidos em cada etapa.

# %% [markdown]
# ### Etapa 1: Ambiente pronto
#
# A SparkSession já está criada para você focar na atividade.

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, avg, sum, count

spark = (
    SparkSession.builder
    .appName("S19A3_Atividade_Aluno")
    .master("local[*]")
    .getOrCreate()
)

csv_path = "DADOSANO2C6B3S19A3_auxiliar.csv"

print("SparkSession ativa")

# %% [markdown]
# ### Etapa 2: Leitura do arquivo
#
# Leia o arquivo CSV com:
#
# - `header = true`
# - `inferSchema = true`
#
# Depois:
#
# - mostre 8 linhas do DataFrame;
# - exiba o schema.

# %%
# TODO: leia o CSV com header=True e inferSchema=True
# TODO: salve o resultado em df

# TODO: mostre 8 linhas

# TODO: exiba o schema

# %% [markdown]
# ### Etapa 3: Filtro simples
#
# Selecione apenas as vendas com `valor_venda` maior que `1000`.
#
# Depois:
#
# - mostre o resultado com `show()`.

# %%
# TODO: filtre as vendas com valor_venda > 1000

# TODO: mostre o resultado

# %% [markdown]
# ### Etapa 4: Filtro com múltiplas condições
#
# Selecione apenas as vendas em que:
#
# - `setor` seja `"Eletrônicos"`
# - e `regiao` seja `"Sul"`
#
# Depois:
#
# - mostre o resultado com `show()`.

# %%
# TODO: filtre as vendas com setor == "Eletrônicos" e regiao == "Sul"

# TODO: mostre o resultado

# %% [markdown]
# ### Etapa 5: Filtro com `isin()`
#
# Selecione apenas as vendas em que a `regiao` seja:
#
# - `"Sudeste"`
# - ou `"Sul"`
#
# Depois:
#
# - mostre o resultado com `show()`.

# %%
# TODO: filtre as vendas usando isin() para as regiões Sudeste e Sul

# TODO: mostre o resultado

# %% [markdown]
# ### Etapa 6: Agrupamento com `count()`
#
# Agrupe os dados por `setor` e conte quantas vendas existem em cada grupo.
#
# Depois:
#
# - mostre o resultado com `show()`.

# %%
# TODO: agrupe por setor e conte os registros

# TODO: mostre o resultado

# %% [markdown]
# ### Etapa 7: Agrupamentos com `sum()` e `avg()`
#
# Agora calcule, por `setor`:
#
# 1. a soma de `valor_venda`;
# 2. a média de `valor_venda`.
#
# Mostre os dois resultados.

# %%
# TODO: agrupe por setor e calcule a soma de valor_venda

# TODO: mostre o resultado

# TODO: agrupe por setor e calcule a média de valor_venda

# TODO: mostre o resultado

# %% [markdown]
# ### Etapa 8: Múltiplas agregações com `agg()`
#
# Faça uma única análise por `setor`, calculando ao mesmo tempo:
#
# - quantidade de vendas;
# - soma de `valor_venda`;
# - média de `valor_venda`.
#
# Depois:
#
# - mostre o resultado com `show()`.

# %%
# TODO: use groupBy() com agg() para calcular count, sum e avg por setor

# TODO: mostre o resultado

# %% [markdown]
# ## Entrega
#
# Antes de finalizar, verifique se o notebook contém:
#
# - leitura correta do arquivo;
# - filtros pedidos;
# - agrupamentos pedidos;
# - saídas com `show()` em todas as etapas.
#
# Salve o notebook e entregue conforme a orientação do professor.
