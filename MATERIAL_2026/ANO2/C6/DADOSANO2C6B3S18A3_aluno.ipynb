# %% [markdown]
# <h1 style="text-align: center;">TÉCNICO EM CIÊNCIA DE DADOS</h1>
# <h1 style="text-align: center;">Tratando e transformando dados no PySpark</h1>
# <br>
#
# **Componente:** Fundamentos de Ambientes e Arquitetura de Dados
# <br>
# **Unidade Curricular:** Introdução ao PySpark e Processamento Distribuído
# <br>
# **Tema da Semana:** Transformações em DataFrames
# <br>
# **Semana 18 - Aula 3**
# <br>
# **Atividade:** Limpeza e transformação de dados

# %% [markdown]
# ## Objetivo prático
#
# Aplicar os conceitos estudados na semana em uma atividade de preparação de dados no PySpark.
#
# Ao longo da atividade, você deverá:
#
# 1. Ler um arquivo CSV com `header` e `inferSchema`.
# 2. Verificar o schema do DataFrame.
# 3. Converter tipos de colunas com `cast()`.
# 4. Comparar o efeito de `dropna()`.
# 5. Preencher valores nulos com `fillna()`.
# 6. Substituir valores com `replace()`.
# 7. Criar novas colunas com `withColumn()`.
# 8. Renomear colunas com `withColumnRenamed()`.
# 9. Adicionar uma coluna fixa com `lit()`.

# %% [markdown]
# ## Lista de materiais
#
# - Ambiente com PySpark configurado.
# - Este notebook.
# - Arquivo auxiliar no mesmo diretório: `DADOSANO2C6B3S18A3_auxiliar.csv`.

# %% [markdown]
# ## Orientações
#
# - Execute as células na ordem.
# - Complete as células com `# TODO`.
# - Observe como o DataFrame muda após cada transformação.
# - Ao final, o conjunto de dados deve ficar pronto para análise.

# %% [markdown]
# ### Etapa 1: Ambiente pronto
#
# A SparkSession já está criada para você focar na atividade.

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, lit

spark = (
    SparkSession.builder
    .appName("S18A3_Atividade_Aluno")
    .master("local[*]")
    .getOrCreate()
)

csv_path = "DADOSANO2C6B3S18A3_auxiliar.csv"

print("SparkSession ativa")

# %% [markdown]
# ### Etapa 2: Leitura do arquivo
#
# Leia o arquivo CSV com:
#
# - `header = true`
# - `inferSchema = true`
#
# Depois:
#
# - mostre 8 linhas do DataFrame;
# - exiba o schema.

# %%
# TODO: leia o CSV com header=True e inferSchema=True
# TODO: salve o resultado em df

# TODO: mostre 8 linhas

# TODO: exiba o schema

# %% [markdown]
# ### Etapa 3: Ajustando tipos com cast()
#
# Converta as colunas abaixo para os tipos indicados:
#
# - `quantidade` → `int`
# - `preco_unitario` → `double`
#
# Em seguida, mostre novamente o schema.

# %%
# TODO: converta a coluna quantidade para int

# TODO: converta a coluna preco_unitario para double

# TODO: exiba o schema atualizado

# %% [markdown]
# ### Etapa 4: Comparando estratégias para valores nulos
#
# Crie um novo DataFrame chamado `df_sem_nulos` usando `dropna()`.
#
# Depois:
#
# - conte quantas linhas existem no DataFrame original;
# - conte quantas linhas restam em `df_sem_nulos`.
#
# Compare os resultados.

# %%
# TODO: crie df_sem_nulos com dropna()

# TODO: mostre a quantidade de linhas do DataFrame original

# TODO: mostre a quantidade de linhas do DataFrame sem nulos

# %% [markdown]
# ### Etapa 5: Preenchendo nulos e substituindo valores
#
# Agora prepare o DataFrame para manter os registros.
#
# Faça os seguintes tratamentos em `df`:
#
# 1. Preencha os valores nulos de `quantidade` com `0`.
# 2. Preencha os valores nulos de `preco_unitario` com `0`.
# 3. Substitua o valor `"indefinida"` por `"não informada"` na coluna `regiao`.
# 4. Substitua o valor `"pend"` por `"pendente"` na coluna `status_entrega`.
#
# Depois, mostre 10 linhas do DataFrame.

# %%
# TODO: preencha os nulos de quantidade com 0

# TODO: preencha os nulos de preco_unitario com 0

# TODO: substitua "indefinida" por "não informada" na coluna regiao

# TODO: substitua "pend" por "pendente" na coluna status_entrega

# TODO: mostre 10 linhas do DataFrame

# %% [markdown]
# ### Etapa 6: Criando e reorganizando colunas
#
# Faça as seguintes transformações:
#
# 1. Crie a coluna `valor_total_pedido`, multiplicando `quantidade` por `preco_unitario`.
# 2. Renomeie a coluna `cliente` para `nome_cliente`.
# 3. Crie a coluna `origem_dados` com o valor fixo `"csv_pedidos"`.
#
# Depois:
#
# - mostre 10 linhas com `truncate=False`;
# - exiba o schema final.

# %%
# TODO: crie a coluna valor_total_pedido

# TODO: renomeie cliente para nome_cliente

# TODO: crie a coluna origem_dados com lit("csv_pedidos")

# TODO: mostre 10 linhas com truncate=False

# TODO: exiba o schema final

# %% [markdown]
# ## Interpretação (responda no notebook)
#
# 1. Qual foi a diferença entre usar `dropna()` e usar `fillna()` neste conjunto de dados?
# 2. Por que foi importante substituir os valores `"indefinida"` e `"pend"`?
# 3. Qual é a utilidade da coluna `valor_total_pedido`?
# 4. O que mudou no DataFrame após renomear a coluna `cliente`?
# 5. Em que situação uma coluna fixa como `origem_dados` pode ser útil?

# %% [markdown]
# **Respostas (digite aqui):**
#
# 1.
#
# 2.
#
# 3.
#
# 4.
#
# 5.
