# %% [markdown]
# <h1 style="text-align: center;">TÉCNICO EM CIÊNCIA DE DADOS</h1>
# <h1 style="text-align: center;">Explorando um DataFrame no PySpark</h1>
# <br>
#
# **Componente:** Fundamentos de Ambientes e Arquitetura de Dados
# <br>
# **Unidade Curricular:** Introdução ao PySpark e Processamento Distribuído
# <br>
# **Tema da Semana:** Leitura de dados
# <br>
# **Semana 17 - Aula 3**
# <br>
# **Atividade:** Leitura e exploração inicial com CSV

# %% [markdown]
# ## Objetivo prático
# Aplicar os conceitos das aulas 1 e 2 em uma atividade guiada:
# 1. Usar `read.csv()` para leitura simples.
# 2. Usar `options` com `inferSchema` para leitura configurada.
# 3. Usar `show()` e `describe()` para exploração inicial dos dados.

# %% [markdown]
# ## Lista de materiais
# - Ambiente com PySpark configurado.
# - Este notebook.
# - Arquivo auxiliar no mesmo diretório: `DADOSANO2C6B3S17A3_auxiliar.csv`.

# %% [markdown]
# ## Orientações
# - Execute as células na ordem.
# - Complete as células com `# TODO`.
# - Compare os resultados entre a leitura simples e a leitura com opções.

# %% [markdown]
# ### Etapa 1: Ambiente pronto (SparkSession)
# A SparkSession já está criada para você focar na atividade.

# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
    .appName("S17A3_Atividade_Aluno")
    .master("local[*]")
    .getOrCreate()
)

csv_path = "DADOSANO2C6B3S17A3_auxiliar.csv"

print("SparkSession ativa")

# %% [markdown]
# ### Etapa 3.1: `read.csv()`
# Faça a leitura simples do CSV (sem opções) e mostre as 5 primeiras linhas.

# %%
# TODO: faça a leitura simples (sem header e sem inferSchema)
# Dica: spark.read.csv(csv_path)

# TODO: mostre as 5 primeiras linhas

# %% [markdown]
# ### Etapa 3.2: `options` e `inferSchema`
# Agora leia o mesmo arquivo com:
# - `header = true`
# - `inferSchema = true`
# - `sep = ","`
#
# Depois, mostre as 5 primeiras linhas.

# %%
# TODO: leia o CSV com as opções solicitadas e salve em df_csv

# TODO: mostre as 5 primeiras linhas de df_csv

# %% [markdown]
# ### Etapa 4: Comparando os schemas
# Mostre o schema do DataFrame lido sem opções e o schema do DataFrame com opções.

# %%
# TODO: mostre o schema da leitura simples

# TODO: mostre o schema da leitura com opções

# %% [markdown]
# ### Etapa 3.3: `show()` e `describe()`
# Agora use o DataFrame com opções (`df_csv`) para uma exploração inicial.

# %%
# TODO: mostre 5 linhas de df_csv (truncate=False)

# TODO: execute describe() em df_csv

# %% [markdown]
# ## Interpretação (responda no notebook)
# 1. Qual a principal diferença entre a leitura simples e a leitura com `header/inferSchema`?
# 2. No `describe()`, quais métricas aparecem para as colunas numéricas?
# 3. Qual a utilidade de rodar `show()` antes de começar transformações?

# %% [markdown]
# **Respostas (digite aqui):**
#
# 1.
#
# 2.
#
# 3.
