# %% [markdown]
# <h1 style="text-align: center;">TÉCNICO EM CIÊNCIA DE DADOS</h1>
# <h1 style="text-align: center;">Atividade Prática</h1>
# <br>
# <br>
#
# **Componente:** Fundamentos de Ambientes e Arquitetura de Dados
# <br>
# **Unidade Curricular:** Introdução ao PySpark e Processamento Distribuído
# <br>
# **Tema da Semana:** Iniciando com DataFrames
# <br>
# **Semana 16 – Aula 3**
# <br>
# **Aula 3:** Criação e inspeção de DataFrames
#
# <h2 align="center">Aplicando show() e printSchema()</h2>

# %% [markdown]
# ## Objetivo prático
#
# Aplicar a criação e a inspeção de DataFrames em PySpark local, utilizando:
#
# - `spark.range()` para criar o DataFrame
# - `withColumn()` para criar colunas
# - `show()` para visualizar os dados
# - `printSchema()` para inspecionar a estrutura (schema)

# %% [markdown]
# ## Lista de Materiais
#
# - Computador com Anaconda (Jupyter Notebook) ou VS Code com suporte a `.ipynb`.
# - Ambiente com PySpark configurado.
# - Este arquivo **DADOSANO2C6B3S16A3_aluno.ipynb**.

# %% [markdown]
# ## Orientações de execução
#
# - Execute as células **na ordem**.
# - Em células com **# TODO**, você deve escrever o código.
# - Quando terminar uma etapa, compare seu resultado com o que está sendo pedido na tarefa.

# %% [markdown]
# ### Etapa 1: Iniciando a SparkSession
#
# Execute a célula abaixo para iniciar o ambiente do Spark.

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F

spark = (
    SparkSession.builder
    .appName("S16_A3_Prática_DataFrames")
    .master("local[*]")
    .getOrCreate()
)

spark.sparkContext.setLogLevel("ERROR")
print("SparkSession iniciada com sucesso.")

# %% [markdown]
# ### Etapa 2: Criando o DataFrame com `spark.range()`
#
# Crie um DataFrame com **id de 101 a 110** usando `spark.range()`.
#
# Resultado esperado: um DataFrame com **uma coluna `id`** e **10 linhas**.

# %%
# TODO: crie o DataFrame df com id de 101 a 110 usando spark.range()
# Dica: spark.range(inicio, fim)

# %% [markdown]
# ### Verificação rápida
#
# 1) Rode `df.show(5)` para conferir as **primeiras 5 linhas**.
# 2) Depois rode `df.count()` para conferir a quantidade de linhas (deve ser 10).

# %%
# TODO: mostre as 5 primeiras linhas (use df.show(5))
# TODO: conte as linhas (use df.count())

# %% [markdown]
# ### Etapa 3: Criando colunas no DataFrame
#
# Agora adicione as colunas:
#
# - `nome` → "Participante " + id
# - `turno` → "Manhã" (valor fixo)
# - `nota` → ((id % 10) * 0.7 + 3) como **double**
#
# Resultado esperado: 4 colunas (id, nome, turno, nota)

# %%
# TODO: adicione as colunas usando withColumn()
# Dicas:
# - F.concat(F.lit("Participante "), F.col("id"))
# - F.lit("Manhã")
# - ((F.col("id") % 10) * 0.7 + 3).cast("double")

# %% [markdown]
# ### Etapa 4: Visualizando os dados
#
# Execute `show()` para exibir o DataFrame com as novas colunas.
#
# Resultado esperado: uma tabela com id, nome, turno e nota.

# %%
# TODO: execute show() para visualizar o DataFrame

# %% [markdown]
# ### Etapa 5: Inspecionando a estrutura (schema)
#
# Execute `printSchema()` para ver a estrutura do DataFrame.
#
# Resultado esperado: ver os nomes das colunas e tipos (ex.: id = long, nome = string, nota = double).

# %%
# TODO: execute printSchema() para visualizar o schema

# %% [markdown]
# ## Interpretação (responda no próprio notebook)
#
# Responda de forma objetiva (1 a 3 linhas cada).
#
# 1) O que o `show()` apresenta?
# 2) O que o `printSchema()` apresenta?
# 3) Qual coluna ficou com tipo `double`? Por quê?
# 4) Se a coluna `nota` fosse texto (string), o que poderia dar errado em cálculos?

# %% [markdown]
# **Respostas (digite aqui):**
#
# 1)
# 2)
# 3)
# 4)
