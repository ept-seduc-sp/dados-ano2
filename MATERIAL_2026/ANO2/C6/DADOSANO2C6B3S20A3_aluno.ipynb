# %% [markdown]
# <h1 style="text-align: center;">TÉCNICO EM CIÊNCIA DE DADOS</h1>
# <h1 style="text-align: center;">Datas e janelas no PySpark</h1>
# <br>
#
# **Componente:** Fundamentos de Ambientes e Arquitetura de Dados
# **Unidade Curricular:** Introdução ao PySpark e Processamento Distribuído
# **Tema da Semana:** Datas e janelas
# **Semana 20 - Aula 3**
# **Atividade:** Análise temporal de pedidos

# %% [markdown]
# ## Objetivo prático
#
# Aplicar os conceitos estudados na semana em uma atividade de análise temporal no PySpark.
#
# Ao longo da atividade, você deverá:
#
# 1. Ler um arquivo CSV com `header` e `inferSchema`.
# 2. Verificar o schema do DataFrame.
# 3. Converter colunas de texto para data com `to_date()`.
# 4. Criar colunas temporais com `year()` e `month()`.
# 5. Calcular diferença entre datas com `datediff()`.
# 6. Utilizar `current_date()` para comparar uma data com o dia atual.
# 7. Formatar datas com `date_format()`.
# 8. Interpretar os resultados gerados em cada etapa.

# %% [markdown]
# ## Lista de materiais
#
# - Ambiente com PySpark configurado.
# - Este notebook.
# - Arquivo auxiliar no mesmo diretório: `DADOSANO2C6B3S20A3_auxiliar.csv`.

# %% [markdown]
# ## Orientações
#
# - Execute as células na ordem.
# - Complete as células com `# TODO`.
# - Observe como os dados mudam após cada transformação.
# - Compare as diferenças entre as colunas originais e as colunas criadas.
# - Ao final, o notebook deve apresentar os resultados pedidos em cada etapa.

# %% [markdown]
# ### Etapa 1: Ambiente pronto
#
# A SparkSession já está criada para você focar na atividade.

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, to_date, year, month, datediff, current_date, date_format

spark = (
    SparkSession.builder
    .appName("S20A3_Atividade_Aluno")
    .master("local[*]")
    .getOrCreate()
)

csv_path = "DADOSANO2C6B3S20A3_auxiliar.csv"

print("SparkSession ativa")

# %% [markdown]
# ### Etapa 2: Leitura do arquivo
#
# Leia o arquivo CSV com:
#
# - `header = true`
# - `inferSchema = true`
#
# Depois:
#
# - mostre 8 linhas do DataFrame;
# - exiba o schema.

# %%
# TODO: leia o CSV com header=True e inferSchema=True
# TODO: salve o resultado em df

# TODO: mostre 8 linhas

# TODO: exiba o schema

# %% [markdown]
# ### Etapa 3: Conversão de datas com `to_date()`
#
# As colunas `data_pedido` e `data_entrega` precisam estar no tipo data para permitir cálculos corretos.
#
# Faça o seguinte:
#
# 1. converta `data_pedido` para uma nova coluna chamada `pedido_convertido`;
# 2. converta `data_entrega` para uma nova coluna chamada `entrega_convertida`;
# 3. mostre o resultado com `show()`.

# %%
# TODO: crie a coluna pedido_convertido com to_date()
# TODO: crie a coluna entrega_convertida com to_date()

# TODO: mostre o resultado

# %% [markdown]
# ### Etapa 4: Colunas temporais com `year()` e `month()`
#
# Agora crie duas novas colunas com base em `pedido_convertido`:
#
# - `ano_pedido`
# - `mes_pedido`
#
# Depois, mostre o resultado.

# %%
# TODO: crie a coluna ano_pedido
# TODO: crie a coluna mes_pedido

# TODO: mostre o resultado

# %% [markdown]
# ### Etapa 5: Diferença entre datas com `datediff()`
#
# Calcule quantos dias se passaram entre `pedido_convertido` e `entrega_convertida`.
#
# Crie uma nova coluna chamada `dias_entrega` e exiba o resultado.

# %%
# TODO: crie a coluna dias_entrega com datediff()

# TODO: mostre o resultado

# %% [markdown]
# ### Etapa 6: Data atual com `current_date()`
#
# Agora calcule quantos dias se passaram entre a data do pedido e a data atual.
#
# Crie uma nova coluna chamada `dias_desde_pedido` e mostre o resultado.

# %%
# TODO: crie a coluna data_atual com current_date()
# TODO: crie a coluna dias_desde_pedido com datediff()

# TODO: mostre o resultado

# %% [markdown]
# ### Etapa 7: Formatação com `date_format()`
#
# Crie uma nova coluna chamada `pedido_formatado` usando o formato `dd/MM/yyyy`.
#
# Depois, mostre o resultado.

# %%
# TODO: crie a coluna pedido_formatado com date_format()

# TODO: mostre o resultado

# %% [markdown]
# ### Etapa 8: Seleção final para análise
#
# Exiba apenas as colunas abaixo:
#
# - `cliente`
# - `cidade`
# - `pedido_formatado`
# - `ano_pedido`
# - `mes_pedido`
# - `dias_entrega`
# - `dias_desde_pedido`
#
# Depois, mostre o resultado final com `show()`.

# %%
# TODO: selecione apenas as colunas pedidas

# TODO: mostre o resultado final

# %% [markdown]
# ## Entrega
#
# Antes de finalizar, verifique se o notebook contém:
#
# - leitura correta do arquivo;
# - conversão das datas;
# - criação de colunas temporais;
# - cálculo da diferença entre datas;
# - exibição dos resultados em todas as etapas.
#
# Salve o notebook e entregue conforme a orientação do professor.
