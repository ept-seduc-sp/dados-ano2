# %% [markdown]
# <h1 style="text-align: center;">TÉCNICO EM CIÊNCIA DE DADOS</h1>
# <h1 style="text-align: center;">Roteiro de Atividade Prática</h1>
# <br>
# <br>
#
# **Componente:** Programação Aplicada à Ciência de Dados
# <br>
# **Unidade Curricular:** Lógica de Programação e Fundamentos de Python
# <br>
# **Tema da Semana:** Controle de laços: break e continue
# <br>
# **Semana 11**
# <br>
# **Aula 4:** Exercícios de fixação e revisão final da unidade

# %% [markdown]
# <h2 align="center">Controle de Fluxo e Limpeza de Dados em Python: Aplicando break e continue</h2>

# %% [markdown]
# ## Objetivos da Atividade
#
# - Revisar os principais conceitos da unidade: lógica, variáveis, operadores, condicionais e laços.
# - Aplicar de forma integrada os conteúdos em um exercício prático de programação em Python.
# - Refletir sobre o próprio desempenho e aprendizado ao longo da unidade.
# - Verificar a aprendizagem por meio da resolução e análise de um desafio final.

# %% [markdown]
# ## Lista de Materiais
# - Computador com **Anaconda (Jupyter Notebook)** ou **Visual Studio Code** instalado, com suporte a arquivos `.ipynb`.
# - Arquivo **“DADOSANO1C2B2S11A4_aluno.ipynb”** fornecido pelo professor.

# %% [markdown]
# ## O que aprendemos nesta unidade
#
# Nesta unidade, estudamos os **fundamentos da lógica de programação** e como o **Python** utiliza esses conceitos para automatizar tarefas.
# Aprendemos a usar **variáveis, operadores, estruturas condicionais e laços de repetição**, que são essenciais para resolver problemas de forma estruturada e eficiente.
#
# Na **Ciência de Dados**, esses conceitos são cruciais para **organizar, limpar e analisar dados**, garantindo que as decisões do programa sejam lógicas e confiáveis.
#
# ### Base Teórica
#
# - **Lógica e Fluxogramas**: Estruturação do raciocínio em etapas, representadas visualmente por fluxogramas.
# - **Introdução ao Python**: Linguagem moderna e simples, muito usada em ciência de dados pela sua clareza.
# - **Variáveis e Tipos de Dados**: Armazenam informações (números, textos, valores lógicos) durante a execução.
# - **Operadores**: Realizam cálculos, comparações e decisões lógicas.
#   - **Aritméticos**: Operações matemáticas.
#   - **Relacionais**: Comparações.
#   - **Lógicos**: Operações de decisão ("e", "ou", "não").
# - **Estruturas Condicionais**: Permitem executar ações diferentes com base em condições.
# - **Laços de Repetição**: Executam ações múltiplas vezes.
#   - **for**: Repete um número definido de vezes.
#   - **while**: Repete enquanto a condição for verdadeira.
# - **Controle de Laços**: Comandos para controlar loops.
#   - **break**: Interrompe o laço.
#   - **continue**: Salta para a próxima repetição.

# %% [markdown]
# ## Orientações para Responder às Atividades
#
# 1. **Quando a questão exigir que você rode um código:**
#    - Utilize o **Jupyter Notebook** para rodar o código.
#
# 2. **Quando for necessário digitar uma resposta:**
#    - Clique **duas vezes** na célula que contém a mensagem "Escreva sua resposta aqui". Após fazer isso, a célula se tornará **editável**.
#    - Não se preocupe, você não precisa saber Markdown para utilizá-la. Basta **digitar normalmente**.
#    - Após escrever sua resposta, clique no ícone **✓** (certo) no canto superior direito da célula para rodar e **salvar sua resposta**.
#
# ---

# %% [markdown]
# ## Atividade 1: Registro de Gastos
#
# **Objetivo:** Praticar um laço infinito com `while True:` e usar `break` para encerrar o registro quando o usuário digitar um comando específico.
#
# **Desafio:** Você está **montando uma lista de gastos do mês** para, depois, analisar o total e os valores registrados.
# O programa vai pedir um valor repetidamente até você digitar **"parar"**.
#
# Crie um programa que:
# - peça um valor de gasto (ex: `35.90`)
# - registre/mostre o valor digitado
# - pare quando o usuário digitar **"parar"**
#
#
# **Instruções**
#
# 1. Crie um laço infinito com `while True:`.
# 2. Dentro do laço, peça um valor com `input()`:
#    - Exemplo: `gasto = input("Digite um gasto (ou 'parar'): ")`
# 3. Verifique se `gasto` é igual a **"parar"**:
#    - Se for, imprima **"Registro finalizado."** e use `break`.
#    - Se não for, imprima: `f"Gasto registrado: R$ {gasto}"`
# 4. Após o laço, imprima **"Planilha pronta para análise."**

# %%
# Escreva o código aqui

# %% [markdown]
# ## Atividade 2: Limpador de Dados Corrompidos
#
# **Objetivo**: Limpar dados corrompidos. Vamos pular batimentos inválidos usando `continue`.
#
# **Desafio:**
# Você tem uma lista de batimentos cardíacos, mas alguns dados são **-1** (corrompidos). Calcule a média dos batimentos válidos.
#
# **Instruções:**
# 1. Dados: `dados_batimentos = [72, 85, -1, 90, -1, 76]`.
# 2. Crie `soma_validos = 0`.
# 3. Use `for` para percorrer os dados e ignore **-1** com `continue`.
# 4. Exiba a média dos batimentos válidos.

# %%
dados_batimentos = [72, 85, -1, 90, -1, 76]

# Escreva o código aqui
