# %% [markdown]
# <h1 style="text-align: center;">TÉCNICO EM CIÊNCIA DE DADOS</h1>
# <h1 style="text-align: center;">Roteiro do Desenvolvendo Juntos</h1>
# <br>
# <br>
#
# **Componente:** Programação Aplicada à Ciência de Dados
# <br>
# **Unidade Curricular:** Manipulação e Estruturação de Dados
# <br>
# **Tema da Semana:** Introdução ao uso do Pandas para manipulação de dados
# <br>
# **Semana 17**
# <br>
# **Aula 2:** Atributos e métodos úteis de DataFrames

# %% [markdown]
# <h2 align="center">Exploração Estrutural de DataFrames</h2>

# %% [markdown]
# ## Objetivos
#
# - Identificar a volumetria de dados com .shape.
#
# - Analisar tipos de variáveis com .dtypes.
#
# - Inspecionar amostras de dados com .head().

# %% [markdown]
# ## Lista de Materiais
# - Computador com **Anaconda (Jupyter Notebook)** ou **Visual Studio Code** instalado, com suporte a arquivos `.ipynb`.
# - Arquivo **"DADOSANO1C2B3S17A2_desenvolvendo_juntos.ipynb"** fornecido pelo professor.
# - Arquivo **"DADOSANO1C2B3S17A2_auxiliar1.csv"** fornecido pelo professor.

# %% [markdown]
# Execute o código abaixo para instalar as bibliotecas (se for necessário) para usar o Pandas com leitura de arquivos.

# %%
# %pip install pandas openpyxl

# %% [markdown]
# ## Prática Guiada Passo a Passo
#
# Cada etapa deve ser demonstrada pelo professor antes de os alunos repetirem, garantindo compreensão e conexão com a rotina de um profissional da área.

# %%
import pandas as pd

# %% [markdown]
# ### Etapa 1: Preparação Inicial
#
# Carregar o arquivo com .read_csv().

# %%
df = pd.read_csv('DADOSANO1C2B3S17A2_auxiliar1.csv')

# %% [markdown]
# ### Etapa 2: Dimensões
#
# Executar df.shape e interpretar o resultado (linhas, colunas).

# %%
# Retorna (linhas, colunas)
df.shape

# %% [markdown]
# ### Etapa 3: Visualização
#
# Utilizar .head(10) para observar as dez primeiras entradas.

# %%
# Mostra as 10 primeiras linhas
df.head(10)

# %% [markdown]
# ## Mapeamento
#
# Exibir df.columns para validar os nomes das variáveis.

# %%
# Lista os nomes das colunas
df.columns
