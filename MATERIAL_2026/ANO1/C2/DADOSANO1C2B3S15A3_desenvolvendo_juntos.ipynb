# %% [markdown]
# <h1 style="text-align: center;">TÉCNICO EM CIÊNCIA DE DADOS</h1>
# <h1 style="text-align: center;">Roteiro do Desenvolvendo Juntos</h1>
# <br>
# <br>
#
# **Componente:** Programação Aplicada à Ciência de Dados
# <br>
# **Unidade Curricular:** Manipulação e Estruturação de Dados
# <br>
# **Tema da Semana:** Importação de arquivos estruturados
# <br>
# **Semana 15**
# <br>
# **Aula 3:** Verificação da estrutura dos dados importados

# %% [markdown]
# <h2 align="center">Identificando os Dados</h2>

# %% [markdown]
# ## Objetivos
#
# - Utilizar o método info() para validar tipos de dados.
#
# - Aplicar o método describe() para obter resumos estatísticos.
#
# - Identificar inconsistências entre o tipo de dado esperado e o importado.

# %% [markdown]
# ## Lista de Materiais
# - Computador com **Anaconda (Jupyter Notebook)** ou **Visual Studio Code** instalado, com suporte a arquivos `.ipynb`.
# - Arquivo **"DADOSANO1C2B2S15A3_desenvolvendo_juntos.ipynb"** fornecido pelo professor.
# - Arquivo **"DADOSANO1C2B2S15A3_auxiliar1.csv"** fornecido pelo professor.

# %% [markdown]
# Execute o código abaixo para instalar as bibliotecas (se for necessário) para usar o Pandas com leitura de arquivos.

# %%
# %pip install pandas openpyxl

# %% [markdown]
# ## Prática Guiada Passo a Passo
#
# ### Etapa 1: Preparando o ambiente
#
# O professor demonstrará como importar a biblioteca Pandas e como carregar o CSV.

# %%
import pandas as pd
df = pd.read_csv('DADOSANO1C2B2S15A3_auxiliar1.csv')

# %% [markdown]
# ### Etapa 2: Raio-X dos Dados
#
# O professor executa df.info().

# %%
# O professor executa primeiro:
df.info()

# %% [markdown]
# **O que observar**: Note que as colunas preco e quantidade_estoque possuem apenas 9 valores não-nulos, enquanto o total de entradas é 10. Isso indica que há informações faltando nessas linhas.

# %% [markdown]
# ### Etapa 3: Análise Numérica (Caça ao Erro)
# Veja o resumo estatístico dos números.

# %%
# O professor executa primeiro:
df.describe()

# %% [markdown]
# ### Etapa 4: Desafio Colunas de Texto
# Peça aos alunos para tentarem usar df.describe(include='object') e observarem o que muda no resultado (aparecerão as colunas de texto).

# %%
# Aqui o professor conduzirá o exemplo acima.
