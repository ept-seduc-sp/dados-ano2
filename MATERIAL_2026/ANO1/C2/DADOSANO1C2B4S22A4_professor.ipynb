# %% [markdown]
# <h1 style="text-align: center;">TÉCNICO EM CIÊNCIA DE DADOS</h1>
# <h1 style="text-align: center;">Roteiro de Atividade Prática</h1>
# <br>
# <br>
#
# **Componente:** Programação Aplicada à Ciência de Dados
# <br>
# **Unidade Curricular:** Bibliotecas de manipulação e visualização de dados
# <br>
# **Tema da Semana:** Gráficos básicos com Matplotlib: linha, barra e dispersão
# <br>
# **Semana 22**
# <br>
# **Aula 4:**  Exercícios com gráficos customizados

# %% [markdown]
# <h2 align="center">Refinando o Olhar: Customização de Eixos e Escalas em Projetos</h2>

# %% [markdown]
# ## Objetivos da Atividade
#
# - Utilizar a biblioteca Seaborn para carregamento de dados e visualização rápida de tendências estatísticas.
#
# - Aplicar limites personalizados nos eixos (xticks e yticks) para melhorar a leitura de dados discrepantes.
#
# - Utilizar marcações de pontos e anotações para destacar informações relevantes em gráficos de dispersão.
#
# - Customizar escalas e cores para diferenciar categorias de dados em um contexto de análise real.

# %% [markdown]
# ## Lista de Materiais
# - Computador com **Anaconda (Jupyter Notebook)** ou **Visual Studio Code** instalado, com suporte a arquivos `.ipynb`.
# - Arquivo **"DADOSANO1C2B4S22A4_aluno.ipynb"** fornecido pelo professor.
# - pasta **"DADOSANO1C2B4S22A4_base_de_dados"** fornecido pelo professor.

# %% [markdown]
# ## Descrição do Projeto CineData — Estratégia e Sucesso no Entretenimento
#
# Uma nova produtora de filmes precisa decidir onde investir seu orçamento. Ela possui um banco de dados com milhares de produções, notas do público, orçamentos e faturamentos. O aluno atua como um Cientista de Dados Júnior para identificar quais gêneros são lucrativos e quais as tendências do mercado.

# %% [markdown]
# ## Base Teórica
#
# Na ciência de dados, nem sempre os eixos automáticos do Python são os melhores para contar uma história. Às vezes, precisamos "dar um zoom" em uma parte do gráfico ou mudar os nomes que aparecem nos eixos para que qualquer pessoa entenda.
#
# **Exemplo: Customizando nomes no eixo X**
#
# Se temos números (0, 1) representando categorias, podemos trocá-los por textos:
#
#
# ```python
# import matplotlib.pyplot as plt
#
# x = [0, 1]
# y = [100, 250]
#
# plt.bar(x, y)
# # Customizando os "ticks" (marquinhas) do eixo X
# plt.xticks(x, ['Grupo A', 'Grupo B'])
# plt.show()
# ```
# **Exemplo: Definindo limites no eixo Y**
#
# Para evitar que o gráfico pareça "achatado" ou para focar em um intervalo:
#
# ```python
# plt.scatter(x, y)
# plt.ylim(0, 500) # O eixo Y agora vai obrigatoriamente de 0 a 500
# plt.show()
# ```

# %% [markdown]
# ## Orientações para Responder às Atividades
#
# 1. **Quando a questão exigir que você rode um código:**
#    - Utilize o **Jupyter Notebook** para rodar o código.
#
# 2. **Quando for necessário digitar uma resposta:**
#    - Clique **duas vezes** na célula que contém a mensagem "Escreva sua resposta aqui". Após fazer isso, a célula se tornará **editável**.
#    - Não se preocupe, você não precisa saber Markdown para utilizá-la. Basta **digitar normalmente**.
#    - Após escrever sua resposta, clique no ícone **✓** (certo) no canto superior direito da célula para rodar e **salvar sua resposta**.
# 3. **Quando necessário utilizar um arquivo**
#    - Nas atividades, utilize os arquivos  fornecido pelo professor. Esses arquivos contém os dados necessários para realizar as análises e atividades propostas.
# ---

# %% [markdown]
# Execute o código abaixo para instalar as bibliotecas (se for necessário) para usar o matplotlib.

# %%
# %pip install matplotlib

# %% [markdown]
# # Importação das Bibliotecas para a atividade

# %%
# Rode esta linha antes de começar a atividade para carregar as bibliotecas necessárias.
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Atividade de Aquecimento: Explorando o Dataset "Tips"
#
# Antes de mergulharmos nos dados da CineData, vamos analisar um dataset famoso chamado Tips (gorjetas), que contém registros de contas em um restaurante.

# %%
# Carregando dados prontos da biblioteca Seaborn
df_tips = sns.load_dataset('tips')

# Visualizando as primeiras linhas
print(df_tips.head())

# %% [markdown]
# **Observe as colunas** : total_bill (valor total da conta), tip (gorjeta), sex (gênero), day (dia da semana) e size (número de pessoas na mesa). Comente com sua dupla o que você observa na relação entre essas colunas.

# %% [markdown]
# ## Atividade do Projeto da Unidade CineData Semana 22: O Sucesso em Gráficos
#
# **Contexto:** Agora que mapeamos o volume de filmes, a produtora quer entender a relação financeira: o orçamento investido reflete no faturamento? Além disso, precisamos ver qual o faturamento médio por gênero de forma clara.
#
# **Atividade Prática**
#
# 1. Carga de Dados: Importe o arquivo DADOSANO1C2B4S22A4_base_de_dados/base_de_filmes.csv.
#
# 2. Gráfico de Barras (Faturamento Médio):
#
#     - Calcule a média de faturamento por gênero (Dica: use .groupby('genero')['faturamento_milhoes'].mean()).
#     - Crie o gráfico de barras e use plt.xticks(rotation=45) para que os nomes dos gêneros não fiquem sobrepostos.
#
# 3. Gráfico de Dispersão (Orçamento vs. Faturamento):
#
#     - Crie um gráfico de dispersão com plt.scatter usando a coluna 'orcamento_milhoes' no eixo X e 'faturamento_milhoes' no eixo Y.
#
# 4. Destaque Visual:
#
#     - Identifique um ponto de sucesso (ex: um filme com faturamento muito alto) e use plt.annotate() para escrever "Sucesso de Bilheteria" próximo a esse ponto.
#
# 5. Ajuste de Escala:
#
#     - Se houver filmes com faturamento muito acima da média que "esmagam" a visualização, utilize plt.xlim() e plt.ylim() para focar na massa principal de filmes (ex: até 800 milhões).

# %%
# Escreva o código aqui

# %% [markdown]
# # Gabarito / Expectativas de resposta – Orientações para o professor

# %% [markdown]
# ## Atividade de Aquecimento: Explorando o Dataset "Tips"
#
# **Expectativa de entrega**
#
# Esta atividade serve para que o aluno entenda a estrutura dos dados de datasets carregados diretamente do seaborn.
#
# **Análise Pedagógica:**
#
# Esta etapa serve para o aluno praticar a leitura de dados estruturados e a identificação de padrões simples (correlação) antes de iniciar a manipulação técnica. O foco é desenvolver o "olhar analítico" sobre as variáveis de um problema real de negócio.

# %% [markdown]
# ## Atividade do Projeto da Unidade CineData Semana 22: O Sucesso em Gráficos
#
# **Expectativa de entrega**

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('DADOSANO1C2B4S22A4_base_de_dados/base_de_filmes.csv')

# Gráfico de Barras
faturamento_medio = df.groupby('genero')['faturamento_milhoes'].mean()
faturamento_medio.plot(kind='bar', color='skyblue')
plt.xticks(rotation=45)
plt.title("Faturamento Médio por Gênero")
plt.show()

# Gráfico de Dispersão
plt.scatter(df['orcamento_milhoes'], df['faturamento_milhoes'], alpha=0.5)
plt.xlabel("Orçamento (Milhões)")
plt.ylabel("Faturamento (Milhões)")

plt.annotate("Sucesso de Bilheteria", xy=(200, 1250), xytext=(150, 1000),
             arrowprops=dict(facecolor='black', shrink=0.05))
plt.title("Relação Orçamento vs Faturamento")
plt.show()

# %% [markdown]
# **Análise pedagógica**
#
# O projeto articula os objetos macro (projetos gráficos) e micro (limites e anotações). O uso da rotação nos nomes dos gêneros resolve um problema comum de legibilidade, enquanto a anotação no gráfico de dispersão introduz a capacidade de destacar "insights" específicos, essencial para um Cientista de Dados Júnior.
