# %% [markdown]
# <h1 style="text-align: center;">TÉCNICO EM CIÊNCIA DE DADOS</h1>
# <h1 style="text-align: center;">Roteiro do Desenvolvendo Juntos</h1>
# <br>
# <br>
#
# **Componente:** Programação Aplicada à Ciência de Dados
# <br>
# **Unidade Curricular:** Manipulação e Estruturação de Dados
# <br>
# **Tema da Semana:** Introdução ao uso do Pandas para manipulação de dados
# <br>
# **Semana:** 17
# <br>
# **Aula 3:**  Alterações básicas em DataFrames

# %% [markdown]
# <h2 align="center">Limpando a Base de Vendas</h2>

# %% [markdown]
# ## Objetivos
#
# - Renomear colunas técnicas para nomes amigáveis.
#
# - Definir uma coluna de ID como índice da tabela.
#
# - Criar uma coluna de cálculo de faturamento total.

# %% [markdown]
# ## Lista de Materiais
# - Computador com **Anaconda (Jupyter Notebook)** ou **Visual Studio Code** instalado, com suporte a arquivos `.ipynb`.
# - Arquivo **"DADOSANO1C2B3S17A3_desenvolvendo_juntos.ipynb"** fornecido pelo professor.
# - Arquivo **"DADOSANO1C2B3S17A3_auxiliar1.csv"** fornecido pelo professor.

# %% [markdown]
# Execute o código abaixo para instalar as bibliotecas (se for necessário) para usar o Pandas com leitura de arquivos.

# %%
# %pip install pandas openpyxl

# %% [markdown]
# ## Prática Guiada Passo a Passo
#
# ### Etapa 1: Importação e Leitura
#
# Carregue os dados e já renomeie as colunas necessárias para facilitar a identificação.

# %%
import pandas as pd
df = pd.read_csv('DADOSANO1C2B3S17A3_auxiliar1.csv')
df = df.rename(columns={'cod_prod': 'ID_Produto', 'vl_un': 'Preco_Unitario'})
df.head()

# %% [markdown]
# ### Etapa 2: Índice e Cálculo
#
# Defina o ID_Venda como índice e realize o cálculo matemático da nova coluna.

# %%
df = df.set_index('ID_Venda')
df['Faturamento'] = df['Preco_Unitario'] * df['Qtd']

# %% [markdown]
# ### Etapa 3: Limpeza e Resultado
#
# Remova dados desnecessários e visualize o DataFrame final.

# %%
df = df.drop(columns=['obs_interna'])

# %% [markdown]
# ### Etapa 4: Verificação
#
# Agora verifique o Dataframe utilizando o método .head().

# %%
#digite o código aqui
