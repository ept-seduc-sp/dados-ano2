# %% [markdown]
# <h1 style="text-align: center;">TÉCNICO EM CIÊNCIA DE DADOS</h1>
# <h1 style="text-align: center;">Roteiro de Atividade Prática</h1>
# <br>
# <br>
#
# **Componente:** Programação Aplicada à Ciência de Dados
# <br>
# **Unidade Curricular:** Lógica de Programação e Fundamentos de Python
# <br>
# **Tema da Semana:** Controle de laços: break e continue
# <br>
# **Semana 11**
# <br>
# **Aula 3:** Testes e validação

# %% [markdown]
# <h2 align="center">Controle de Fluxo e Tratamento de Erros</h2>

# %% [markdown]
# ## Objetivos da Atividade
# - Executar um esboço de solução para um problema real utilizando estrutura sequencial, condicional e de repetição em Python.
# - Aplicar testes e validações no código para identificar e tratar erros em dados ou execuções inesperadas.
# - Empregar estruturas de controle (if, for, while, break, continue) para organizar o raciocínio lógico e o fluxo do programa.
# - Corrigir erros de execução (como tipos incorretos, divisões por zero e dados ausentes), garantindo que o programa funcione de forma confiável.

# %% [markdown]
# ## Lista de Materiais
# - Computador com **Anaconda (Jupyter Notebook)** ou **Visual Studio Code** instalado, com suporte a arquivos `.ipynb`.
# - Arquivo **“DADOSANO1C2B2S11A3_aluno.ipynb”** fornecido pelo professor.

# %% [markdown]
# # Base Teórica
#
# Programar em Python exige **organizar o código de forma lógica e estruturada**, usando **sequências, decisões e repetições**.
# Na **Ciência de Dados**, isso é essencial para **validar e limpar os dados**, garantindo resultados confiáveis.
#
#
# ### Estrutura do Código
#
# Um código estruturado segue três blocos principais:
#
# - **Sequência:** execução passo a passo das instruções.
# - **Decisão:** uso de `if`, `elif`, `else` para escolher caminhos.
# - **Repetição:** uso de `for` ou `while` para repetir tarefas.
#
#
#
# ### Controle de Laços
#
# Durante a repetição, usamos comandos para controlar o fluxo:
#
# - **`break`** → interrompe o laço (ex.: parar após muitos erros).
# - **`continue`** → pula para a próxima iteração (ex.: ignorar valores inválidos).
#
# Esses comandos deixam o código mais eficiente e fácil de testar.

# %% [markdown]
# ## Orientações para Responder às Atividades
#
# 1. **Quando a questão exigir que você rode um código:**
#    - Utilize o **Jupyter Notebook** para rodar o código.
#
# 2. **Quando for necessário digitar uma resposta:**
#    - Clique **duas vezes** na célula que contém a mensagem "Escreva sua resposta aqui". Após fazer isso, a célula se tornará **editável**.
#    - Não se preocupe, você não precisa saber Markdown para utilizá-la. Basta **digitar normalmente**.
#    - Após escrever sua resposta, clique no ícone **✓** (certo) no canto superior direito da célula para rodar e **salvar sua resposta**.
#
# ---

# %% [markdown]
# ## Cenário — Aplicando `break` e `continue`
#
# Você está verificando **produtos** em uma lista de vendas.
# - Se o **preço** do produto for **negativo**, o programa deve **interromper** a execução com `break`.
# - Se o **preço** do produto for **`None`** (em branco), o programa deve **pular** para o próximo produto com `continue`.
#
# ### Atividade Prática
# 1. **Reescreva o código abaixo**, preenchendo os espaços indicados com `break` ou `continue`, conforme necessário.
# 2. **Escreva o código na célula onde está escrito "Escreva o código aqui"** e execute-o no Jupyter Notebook para verificar se ele está funcionando corretamente.
# 3. **Responda à pergunta** ao final da atividade.
#
# ```python
# produtos = [100, 150, None, 200, -50, 300]
# soma = 0
# contador = 0
#
# for preco in produtos:
#     if preco is None:
#         _______   # Preencha aqui
#     if preco < 0:
#         print("Erro: preço inválido encontrado.")
#         _______   # Preencha aqui
#     soma += preco
#     contador += 1
#
# print("Média dos preços válidos:", soma / contador)

# %%
# Escreva o código aqui

# %% [markdown]
# ### Pergunta:
# Explique por que é importante organizar o raciocínio lógico antes de escrever o código completo.
#
# (Observação: o loop para ao encontrar a idade -3, antes de considerar o último valor 30.)

# %% [markdown]
# Escreva sua resposta aqui.

# %% [markdown]
# # Gabarito / Expectativas de resposta – Orientações para o professor

# %% [markdown]
# ## Cenário — Aplicando `break` e `continue`

# %% [markdown]
# Código Preenchido:

# %%
idades = [18, 22, None, 25, -3, 30]
soma = 0
contador = 0

for idade in idades:
    if idade is None:
        continue   # pule esta repetição
    if idade < 0:
        print("Erro: idade inválida encontrada.")
        break      # pare completamente o loop
    soma += idade
    contador += 1

print("Média das idades válidas:", soma / contador)
# Out:
# Erro: idade inválida encontrada.
# Média das idades válidas: 21.666666666666668

# %% [markdown]
# ### Pergunta:
# Explique por que é importante organizar o raciocínio lógico antes de escrever o código completo.
#
# Resposta esperada do aluno:
# "Porque planejar antes ajuda a decidir onde usar o break e o continue, evitando erros e tornando o programa mais claro."

# %% [markdown]
# ### Análise Pedagógica:
#
# O professor deve observar se o aluno entende a importância do planejamento e da organização do raciocínio lógico na programação. O planejamento antecipado ajuda o aluno a identificar de forma clara onde e quando utilizar estruturas de controle como break e continue. Além disso, a atividade testa a habilidade do aluno de prever o comportamento do loop, garantindo que a execução do código ocorra da melhor forma e sem erros.
