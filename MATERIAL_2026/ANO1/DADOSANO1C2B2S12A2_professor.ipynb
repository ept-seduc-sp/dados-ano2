# %% [markdown]
# <h1 style="text-align: center;">TÉCNICO EM CIÊNCIA DE DADOS</h1>
# <h1 style="text-align: center;">Roteiro de Atividade Prática</h1>
# <br>
# <br>
#
# **Componente:** Programação Aplicada à Ciência de Dados
# <br>
# **Unidade Curricular:** Manipulação e Estruturação de Dados
# <br>
# **Tema da Semana:** Listas e tuplas na estruturação de dados
# <br>
# **Semana 12**
# <br>
# **Aula 2:** Manipulação de listas

# %% [markdown]
# <h2 align="center">Organizando e limpando dados com listas</h2>

# %% [markdown]
# ## Objetivos da Atividade
# - Aplicar os métodos append, insert e remove para atualizar coleções de dados.
# - Representar dados em formato de tabela usando listas aninhadas e percorrê-las.
# - Utilizar list comprehension para filtrar e transformar dados de forma simples e legível.

# %% [markdown]
# ## Lista de Materiais
# - Computador com **Anaconda (Jupyter Notebook)** ou **Visual Studio Code** instalado, com suporte a arquivos `.ipynb`.
# - Arquivo **“DADOSANO1C2B2S12A2_aluno.ipynb”** fornecido pelo professor.

# %% [markdown]
# ## Base Teórica
#
# ### Métodos de lista
#
# append(valor): adiciona no final.
#
# insert(pos, valor): insere na posição indicada.
#
# remove(valor): remove a 1ª ocorrência do valor.
# ````python
# itens = ["A", "B"]
# itens.append("C")     # ["A","B","C"]
# itens.insert(1, "X")  # ["A","X","B","C"]
# itens.remove("B")     # ["A","X","C"]
# ````
#
# ### Listas aninhadas
#
# É uma “lista de listas”. Pense como uma tabela (linhas e colunas).
# Você acessa assim: tabela[linha][coluna].
#
# Exemplo: cada aluno tem [nome, nota].
#
# ```python
# alunos = [["Ana", 9], ["João", 7]]
#
# print(alunos[0])        # ["Ana", 9]  -> primeira linha
# print(alunos[0][0])     # "Ana"       -> linha 0, coluna 0
# print(alunos[0][1])     # 9           -> linha 0, coluna 1
# print(alunos[0][0], alunos[0][1])  # Ana 9
#
# ```
# Dica rápida para entender:
#
# alunos[0] pega a primeira “linha”
#
# alunos[0][1] pega o segundo item daquela linha
#
# ### List Comprehension
#
# É um jeito mais curto e rápido de criar uma nova lista a partir de outra.
# Você pode filtrar (pegar só alguns) e/ou transformar (modificar os valores).
#
# Molde:
# [expressao for item in lista if condicao]
#
# - for item in lista percorre os elementos
#
# - if condicao filtra (opcional)
#
# - expressao define o que vai entrar na nova lista
#
# Exemplo filtrando aprovadas (nota ≥ 7):
#
# ```python
# notas = [5, 7, 9]
# aprovadas = [n for n in notas if n >= 7]
# print(aprovadas)  # [7, 9]
#
# ```
#
# Exemplo filtrando e transformando ao mesmo tempo (dobrar só as notas ≥ 7):
#
# ```python
# notas = [5, 7, 9]
# dobro_aprovadas = [n * 2 for n in notas if n >= 7]
# print(dobro_aprovadas)  # [14, 18]
# ```

# %% [markdown]
# ## Orientações para Responder às Atividades
#
# 1. **Quando a questão exigir que você rode um código:**
#    - Utilize o **Jupyter Notebook** para rodar o código.
#
# 2. **Quando for necessário digitar uma resposta:**
#    - Clique **duas vezes** na célula que contém a mensagem "Escreva sua resposta aqui". Após fazer isso, a célula se tornará **editável**.
#    - Não se preocupe, você não precisa saber Markdown para utilizá-la. Basta **digitar normalmente**.
#    - Após escrever sua resposta, clique no ícone **✓** (certo) no canto superior direito da célula para rodar e **salvar sua resposta**.
#
# ---

# %% [markdown]
# ### Exerício 1: Atualizando a “lista de métricas” para um dashboard
#
# Você está montando uma lista de métricas para um dashboard (visitas ao site, taxa de conversão, ticket médio). Durante a reunião, novas prioridades surgem e um item sai de escopo.
#
# **Atividade Prática**
#
# 1. Rode o código e observe como fica a lista no final.

# %%
metricas = ["visitas", "conversao"]
metricas.append("ticket_medio")    
metricas.insert(0, "usuarios")     
metricas.remove("conversao")      
print(metricas)
# Out:
# ['usuarios', 'visitas', 'ticket_medio']

# %% [markdown]
# **Pergunta:**
# - Explique, em 2–3 linhas, como esses três métodos ajudam a manter a lista alinhada às decisões do time (prioridade, inclusão e exclusão de itens).

# %% [markdown]
# Escreva sua resposta aqui.

# %% [markdown]
# ---

# %% [markdown]
# ### Exerício 2: Análise de cadastros por cidade
#
# Utilizar listas aninhadas para organizar e analisar dados de cadastros por cidade. Você irá simular uma análise simples, onde os dados de cadastros de diferentes cidades serão armazenados em uma lista de listas e, a partir disso, será possível realizar algumas operações de análise.
#
# **Atividade Prática**
#
# 1. Crie uma lista aninhada chamada cidades, onde cada linha é: [nome_da_cidade, qtd_cadastros]. Use 3 cidades.
#
# 2. Mostre um relatório no terminal, imprimindo uma linha por cidade no formato: Cidade - X cadastros.
#
# 3. Calcule o total de cadastros (somando todas as cidades) e mostre no final.

# %%
# Escreva o código aqui

# %% [markdown]
# # Gabarito / Expectativas de resposta – Orientações para o professor

# %% [markdown]
# ### Exercício 1 — Atualizando a “lista de métricas” para um dashboard
#
# **Resposta esperada (pergunta)**: o aluno deve mencionar que os métodos permitem incluir itens novos, priorizar ordem (com insert) e excluir o que saiu de escopo, deixando a lista alinhada à decisão de produto.
#
# **Análise pedagógica:**
#
# - Indicadores de domínio: aluno reconhece função e efeito na ordem da lista, e entende primeira ocorrência no remove.
#
# - Erros comuns: confundir insert com “substituir”; achar que remove apaga todas as ocorrências.
#
# - Como intervir: peça para o aluno simular a lista linha a linha (antes/depois de cada método) e justificar a escolha da posição no insert.
#
# - Extensão: perguntar “como remover todas as ocorrências?” → esperar while "x" in lista: lista.remove("x") (ou list comprehension).

# %% [markdown]
# ### Exerício 2: Análise de cadastros por cidade
#
# **Resposta esperada:**

# %%
# 1) Lista aninhada: cada linha é [cidade, qtd_cadastros]
cidades = [
    ["BH", 120],
    ["Divinópolis", 45],
    ["Itaúna", 60]
]

# 2) Relatório: uma linha por cidade
print("Relatório de cadastros:")
for cidade, qtd in cidades:
    print(cidade, "-", qtd, "cadastros")

# 3) Total de cadastros
total = 0
for cidade, qtd in cidades:
    total += qtd

print("Total de cadastros:", total)
# Out:
# Relatório de cadastros:
# BH - 120 cadastros
# Divinópolis - 45 cadastros
# Itaúna - 60 cadastros
# Total de cadastros: 225

# %% [markdown]
# **Análise pedagógica:**
#
# Esta atividade ajuda o aluno a entender a ideia de listas aninhadas como “tabela” (cada linha guarda um par de informações: cidade e quantidade). Ao percorrer a lista com for cidade, qtd in cidades, o estudante pratica a leitura organizada de dados, reforça o conceito de desempacotamento (pegar dois valores de uma linha ao mesmo tempo) e aprende uma operação básica de Ciência de Dados: somar valores para obter um total, desenvolvendo noções iniciais de relatório e agregação de dados.
