# %% [markdown]
# <h1 style="text-align: center;">TÉCNICO EM CIÊNCIA DE DADOS</h1>
# <h1 style="text-align: center;">Roteiro de Atividade Prática</h1>
# <br>
# <br>
#
# **Componente:** Programação Aplicada à Ciência de Dados
# <br>
# **Unidade Curricular:** Lógica de Programação e Fundamentos de Python
# <br>
# **Tema da Semana:** Laços de repetição: while
# <br>
# **Semana:** 10
# <br>
# **Aula 4:** Roteirização de algoritmo para solução estruturada

# %% [markdown]
# <h2 align="center">Planejando passo a passo um algoritmo com lógica e decisão</h2>

# %% [markdown]
# ## Objetivos da Atividade
# - **Planejar** e **descrever passo a passo** uma solução estruturada com base em lógica e decisão.
# - **Organizar** etapas e **simular a execução** de um algoritmo simples antes da codificação.
# - **Aplicar o raciocínio lógico** na construção de fluxos que representem decisões computacionais.

# %% [markdown]
# ## Base Teórica
#
# ### O que é roteirizar um algoritmo?
# Roteirizar um algoritmo é **planejar o raciocínio lógico** antes de programar: definir o problema, separar em passos e prever a execução.
# Ajuda a **visualizar o fluxo**, **evitar erros lógicos** e **economizar tempo** (menos retrabalho).
#
# ### As três etapas do planejamento lógico
# 1. **Esboço de lógica (linguagem natural):** descreva o que o algoritmo deve fazer, sem sintaxe.
# 2. **Organização de etapas (pseudocódigo/fluxograma):** transforme o esboço em passos com **sequência**, **decisão** e **repetição**.
# 3. **Simulação da execução:** teste mentalmente com valores de exemplo (linha a linha), prevendo resultados e correções antes do código.
#
# ### Estruturas básicas envolvidas
# | Tipo de estrutura | Função principal                           | Exemplo (pseudo)                 |
# |-------------------|---------------------------------------------|----------------------------------|
# | Sequência         | Executar passos em ordem                     | `ler dado → processar → imprimir`|
# | Decisão           | Escolher caminho conforme condição           | `se x <= 100 então baixo senão ...` |
# | Repetição         | Repetir enquanto condição for verdadeira     | `enquanto i < tamanho faça ...`  |
#
# > **Boa prática:** em laços `while`, use condição **segura** (`i < len(lista)`) e **atualize o índice** uma vez por iteração.

# %% [markdown]
# ### Exercício: Analisando o Consumo das Salas
#
# Você recebeu uma lista com os **consumos médios mensais (em kWh)** de salas de informática do campus.
# Seu papel é **planejar e construir um algoritmo** que percorra a lista, **classifique** cada sala por faixas de consumo e **conte** quantas estão em cada categoria.
#
# **Categorias:**
# - **Baixo consumo:** `≤ 100 kWh`
# - **Médio consumo:** `101 a 200 kWh`
# - **Alto consumo:** `> 200 kWh`
#
# **Desafio:** roteirize o raciocínio completo (**planejamento → organização → simulação → código Python**), usando apenas `if/elif/else` e `while`.
#
# #### Etapa 1 – Esboço de Lógica
# Descreva, em uma folha em linguagem natural, o passo a passo da solução (sem código).
#
# #### Etapa 2 – Organização de etapas
# Converta o esboço para **pseudocódigo** (sem sintaxe de Python).
#
# #### Etapa 3 – Simulação da execução
# Simule com a lista `[80, 150, 230, 95, 210]`, preenchendo uma tabela com **consumo → categoria → contadores**.
#
# #### Etapa 4 – Código
# Implemente em Python a solução com `while`, `if/elif/else` e impressão dos totais por categoria.
#
# **Regras**
# - Use apenas **sequência**, **decisão** e **repetição (`while`)**.
# - **Não** utilize funções prontas de lista como `sum`, `count` etc.

# %%
# Escreva sua solução aqui

# %% [markdown]
# # Gabarito / Expectativas de resposta – Orientações para o professor

# %% [markdown]
# ### Exercício: Analisando o Consumo das Salas

# %% [markdown]
# *Etapa 1 – Esboço de lógica (resposta esperada)**
# 1. Iniciar contadores de baixo, médio e alto com zero.
# 2. Iniciar índice `i = 0`.
# 3. Enquanto houver elementos na lista, ler o consumo atual.
# 4. Decidir a categoria (≤100 → baixo; 101–200 → médio; >200 → alto) e atualizar o contador.
# 5. Avançar o índice e repetir até o final.
# 6. Imprimir totais por categoria.
#
# **Etapa 2 – Pseudocódigo (resposta esperada)**
#
# ```python
# INÍCIO
#     lista_consumos ← [80, 150, 230, 95, 210]
#     baixo ← 0
#     medio ← 0
#     alto ← 0
#     i ← 0
#
#     ENQUANTO i < tamanho(lista_consumos) FAÇA
#         SE lista_consumos[i] <= 100 ENTÃO
#             baixo ← baixo + 1
#         SENÃO SE lista_consumos[i] <= 200 ENTÃO
#             medio ← medio + 1
#         SENÃO
#             alto ← alto + 1
#         FIMSE
#         i ← i + 1
#     FIMENQUANTO
#
#     EXIBIR "Baixo consumo:", baixo
#     EXIBIR "Médio consumo:", medio
#     EXIBIR "Alto consumo:", alto
# FIM
#
# ```
#
# **Etapa 3 – Simulação (resposta esperada)**
#
# | Consumo | Categoria | Contadores (Baixo / Médio / Alto) |
# |--------:|-----------|------------------------------------|
# | 80      | Baixo     | 1 / 0 / 0                         |
# | 150     | Médio     | 1 / 1 / 0                         |
# | 230     | Alto      | 1 / 1 / 1                         |
# | 95      | Baixo     | 2 / 1 / 1                         |
# | 210     | Alto      | 2 / 1 / 2                         |
#
# **Resultado final esperado:** Baixo = 2, Médio = 1, Alto = 2
#
# **Etapa 4 – Código Python (resposta esperada)**
# (ver célula de código abaixo)

# %%
# Analisando o consumo das salas de informática

# Lista de consumos em kWh
consumos = [80, 150, 230, 95, 210]

# Contadores
baixo = 0
medio = 0
alto = 0

# Índice de controle
i = 0

# Estrutura de repetição while
while i < len(consumos):
    valor = consumos[i]

    if valor <= 100:
        baixo += 1
    elif valor <= 200:  # neste ponto, 101..200
        medio += 1
    else:               # > 200
        alto += 1

    i += 1  # atualizar índice ao fim da iteração

print("Salas com baixo consumo:", baixo)
print("Salas com médio consumo:", medio)
print("Salas com alto consumo:", alto)
# Out:
# Salas com baixo consumo: 2
# Salas com médio consumo: 1
# Salas com alto consumo: 2

# %% [markdown]
# > ***Explicação para o professor:***
# >
# > * O código percorre **uma lista de valores de consumo (em kWh)**, classificando cada sala em **baixo**, **médio** ou **alto consumo**, de acordo com faixas predefinidas.
# > * A estrutura **`while`** é usada para percorrer todos os elementos da lista **sem utilizar comandos avançados** como `for` ou funções prontas, reforçando o controle manual de índices e condições de parada.
# > * A tomada de decisão ocorre por meio de **estruturas condicionais (`if`, `elif`, `else`)**, permitindo que o algoritmo escolha corretamente a categoria de cada sala.
# > * O exercício ajuda o estudante a **compreender a interação entre repetição e decisão**, base essencial para a construção de algoritmos mais complexos em etapas futuras.
# > * O resultado mostra, de forma prática, como o **planejamento passo a passo** — do esboço ao código — garante um programa organizado e previsível.
# > * Conceitualmente, o estudante exercita **raciocínio lógico, controle de fluxo e contagem de eventos**, habilidades fundamentais para o raciocínio computacional e para tarefas de análise de dados.
