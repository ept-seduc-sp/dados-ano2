# %% [markdown]
# <h1 style="text-align: center;">TÉCNICO EM CIÊNCIA DE DADOS</h1>
# <h1 style="text-align: center;">Roteiro de Atividade Prática</h1>
# <br>
# <br>
#
# **Componente:** Programação Aplicada à Ciência de Dados
# <br>
# **Unidade Curricular:** Lógica de Programação e Fundamentos de Python
# <br>
# **Tema da Semana:** Dicionários e conjuntos como base para dados estruturados
# <br>
# **Semana 13**
# <br>
# **Aula 3:** Conjuntos e operações básicas

# %% [markdown]
# <h2 align="center">Identificando valores únicos com conjuntos</h2>

# %% [markdown]
# ## Objetivos da Atividade
# - Compreender o uso de conjuntos (sets) em Python.
# - Remover valores duplicados em coleções de dados.
# - Relacionar o uso de conjuntos à limpeza de dados em contextos reais.

# %% [markdown]
# ## Lista de Materiais
# - Computador com **Anaconda (Jupyter Notebook)** ou **Visual Studio Code** instalado, com suporte a arquivos `.ipynb`.
# - Arquivo **“DADOSANO1C2B2S13A3_aluno.ipynb”** fornecido pelo professor.

# %% [markdown]
# ## Base Teórica
#
# ### Limpeza de Dados com Conjuntos (Sets)
# Imagine que você trabalha no marketing de uma empresa e recebeu uma lista gigante de e-mails de clientes. O problema? Muitos e-mails estão repetidos porque as pessoas se cadastraram em várias campanhas diferentes. Enviar mensagens repetidas ou gerar relatórios com esses erros é perda de tempo e passa uma imagem amadora.
#
# Em Ciência de Dados, chamamos isso de duplicidade, e resolvê-la é parte essencial da Limpeza de Dados (Data Cleaning).
#
# O que é um set?
# O Python tem uma estrutura chamada set (conjunto). A principal característica dela é: ela não aceita valores repetidos. Se você tentar colocar o mesmo nome dez vezes, o set guardará apenas um.
#
# **Exemplo 1: Criando um conjunto do zero**
#
# **Conjuntos usam chaves {}**
#
# ```Python
# cidades = {"São Paulo", "Rio de Janeiro", "Curitiba", "São Paulo"}
# print(cidades)
# # Resultado: {'São Paulo', 'Rio de Janeiro', 'Curitiba'}
# ```
# Como remover duplicatas de listas
# Na vida real, os dados costumam vir em listas. Para "limpar" essa lista, usamos a função set() para transformar a lista em um conjunto e remover o que está sobrando automaticamente.
#
# **Exemplo 2: O caso dos e-mails**
#
# ```Python
# emails = ["ana@email.com", "joao@email.com", "ana@email.com", "bia@email.com"]
#
# # A mágica acontece aqui:
# unicos = set(emails)
#
# print(unicos)
# # Resultado no console: {'ana@email.com', 'joao@email.com', 'bia@email.com'}
# ```
#
# Use o set() sempre que precisar de valores únicos. É a ferramenta mais rápida e simples para garantir que seus dados não tenham "lixo" ou repetições desnecessárias antes de começar qualquer análise séria.
#
# ### Operações com Conjuntos: União e Interseção
# Além de remover duplicatas, os conjuntos permitem cruzar informações de bases de dados diferentes de forma muito simples. Imagine que você tem uma lista de clientes que compraram um produto e outra de clientes que clicaram num anúncio.
#
# Exemplo 3: União e Interseção
#
# ```Python
#
# compraram = {"Ana", "Carlos", "João"}
# clicaram = {"Carlos", "Beatriz", "João"}
#
# # União (Geralzão): Todos que interagiram, sem repetir ninguém
# print("União:", compraram | clicaram)
# # Resultado: {'Ana', 'Beatriz', 'Carlos', 'João'}
#
# # Interseção (VIP): Apenas quem fez as duas coisas ao mesmo tempo
# print("Interseção:", compraram & clicaram)
# # Resultado: {'Carlos', 'João'}
# ```
#
# **Entenda os símbolos:**
# **|** (Barra vertical): Faz a União. Junta todos os nomes dos dois grupos e remove as repetições automaticamente.
#
# **&** (E comercial): Faz a Interseção. Mostra apenas quem aparece nas duas listas simultaneamente.
#
# Essas operações são fundamentais para entender o comportamento do público e focar as estratégias de marketing em grupos específicos.

# %% [markdown]
# ## Orientações para Responder às Atividades
#
# 1. **Quando a questão exigir que você rode um código:**
#    - Utilize o **Jupyter Notebook** para rodar o código.
#
# 2. **Quando for necessário digitar uma resposta:**
#    - Clique **duas vezes** na célula que contém a mensagem "Escreva sua resposta aqui". Após fazer isso, a célula se tornará **editável**.
#    - Não se preocupe, você não precisa saber Markdown para utilizá-la. Basta **digitar normalmente**.
#    - Após escrever sua resposta, clique no ícone **✓** (certo) no canto superior direito da célula para rodar e **salvar sua resposta**.
#
# ---

# %% [markdown]
# ## Atividade 1: Limpando dados duplicados de clientes
#
# Você trabalha no setor de marketing digital de uma empresa e precisa preparar uma base de contatos para o disparo de e-mails.
# No entanto, alguns endereços estão repetidos, o que pode causar envio duplicado de mensagens e falhas na análise de métricas.
# Use conjuntos para limpar os dados e deixar a lista organizada.
#
# **Atividade Prática**
#
# 1. Crie uma lista com e-mails, incluindo repetições.
#
# 2. Transforme essa lista em um conjunto.
#
# 3. Exiba no console apenas os e-mails únicos.

# %%
# Escreva o código aqui

# %% [markdown]
# ## Atividade 2: Cruzando dados de vendas e suporte
# Você é técnico em Ciência de Dados em uma empresa que analisa informações de diferentes setores.
# Há duas bases:
#
# - uma com clientes que compraram produtos;
#
# - outra com clientes que abriram chamados no suporte.
#
# Seu objetivo é descobrir:
#
# - todos os clientes que aparecem em pelo menos uma das bases;
#
# - e os que estão nas duas — ou seja, compraram e pediram suporte.
#
# Use conjuntos e as operações de união (|) e interseção (&) para cruzar as informações.

# %%
vendas = {"Ana", "Bruno", "Carla", "Eduardo"}
suporte = {"Bruno", "Daniela", "Carla", "Fernanda"}

print("Clientes únicos:", vendas | suporte)
print("Clientes em comum:", vendas & suporte)
# Out:
# Clientes únicos: {'Bruno', 'Daniela', 'Carla', 'Ana', 'Fernanda', 'Eduardo'}
# Clientes em comum: {'Bruno', 'Carla'}

# %% [markdown]
# Perguntas:
#
# - Qual operador representa a união entre os conjuntos?
#
# - Qual operador representa a interseção?
#
# - Como essa análise ajuda na tomada de decisão em dados?

# %% [markdown]
# Escreva sua resposta aqui.

# %% [markdown]
# ---

# %% [markdown]
# # Gabarito / Expectativas de resposta – Orientações para o professor

# %% [markdown]
# ## Atividade 1: Limpando dados duplicados de clientes
#
# **Expectativa de entrega:**
#
# O estudante deve criar uma lista com e-mails contendo valores repetidos, transformar essa lista em um conjunto (set) e exibir apenas os e-mails únicos no console.
#
# **Código exemplo esperado:**

# %%
# Lista com e-mails repetidos
emails = [
    "ana@email.com",
    "joao@email.com",
    "ana@email.com",
    "bia@email.com",
    "joao@email.com"
]

# Removendo duplicatas com set()
unicos = set(emails)

# Exibindo apenas os e-mails únicos
print("E-mails únicos:", unicos)
# Out:
# E-mails únicos: {'joao@email.com', 'ana@email.com', 'bia@email.com'}

# %% [markdown]
# **Análise pedagógica:**
# O professor deve observar se o estudante compreende que o set() é uma estrutura fundamental para limpeza e deduplicação de dados, etapa essencial no pré-processamento de dados em Ciência de Dados.
# Essa atividade desenvolve a compreensão de como o Python pode automatizar tarefas comuns de limpeza em bases reais.

# %% [markdown]
# ## Atividade 2: Cruzando dados de vendas e suporte
#
# **Expectativa de entrega:**
# O estudante deve executar o código fornecido, compreender o uso dos operadores | (união) e & (interseção), e responder às perguntas relacionando a lógica dos conjuntos à análise de dados integrados.
#
# **Código exemplo esperado:**

# %%
# Conjuntos com clientes de diferentes setores
vendas = {"Ana", "Bruno", "Carla", "Eduardo"}
suporte = {"Bruno", "Daniela", "Carla", "Fernanda"}

# Operações com conjuntos
print("Clientes únicos:", vendas | suporte)
print("Clientes em comum:", vendas & suporte)
# Out:
# Clientes únicos: {'Bruno', 'Daniela', 'Carla', 'Ana', 'Fernanda', 'Eduardo'}
# Clientes em comum: {'Bruno', 'Carla'}

# %% [markdown]
# **Respostas esperadas:**
#
# - Operador de união: |
#
# - Operador de interseção: &
#
# - Utilidade: permite identificar clientes recorrentes em mais de uma base, facilitando a integração e análise cruzada de dados.
#
# **Análise pedagógica:**
# O professor deve reforçar como as operações entre conjuntos representam de forma simples a integração de diferentes fontes de dados, simulando o cruzamento de bases em um contexto real de Ciência de Dados.
# Essa atividade estimula o raciocínio lógico e a capacidade de interpretar relações entre informações distintas.
