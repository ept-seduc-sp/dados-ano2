# %% [markdown]
# <h1 style="text-align: center;">TÉCNICO EM CIÊNCIA DE DADOS</h1>
# <h1 style="text-align: center;">Roteiro de Atividade Prática</h1>
# <br>
# <br>
#
# **Componente:** Programação Aplicada à Ciência de Dados
# <br>
# **Unidade Curricular:** Bibliotecas de manipulação e visualização de dados
# <br>
# **Tema da Semana:** Visualizações com múltiplas variáveis no Seaborn
# <br>
# **Semana 25**
# <br>
# **Aula 4:**  Exercícios integrados com bibliotecas

# %% [markdown]
# <h2 align="center">Conexões de Sucesso: Mapas de Calor e Distribuições</h2>

# %% [markdown]
# ## Base Teórica
#
# **Exemplo de Código:**
# ```python
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
#
# # Exemplo: Correlação entre tempo de estudo e nota
# df = pd.DataFrame({'estudo': [1, 5, 10], 'nota': [4, 7, 10]}, 'tempo': [8,3,9])
# dados_exemplo = df[['estudo', 'nota']] # selecionando apenas colunas específicas
# correlacao = dados_exemplo.corr()
#
# # Gerando o Heatmap
# sns.heatmap(correlacao, annot=True, cmap='coolwarm')
# plt.show()
#
# # Gerando um Histplot de frequências
# sns.histplot(dados_exemplo['nota'], bins=5)
# plt.show()
# ```

# %% [markdown]
# Execute o código abaixo para instalar as bibliotecas (se for necessário) para a aula.

# %%
# %pip install seaborn matplotlib pandas

# %% [markdown]
# # Importação das Bibliotecas para a atividade

# %%
# Rode esta linha antes de começar a atividade para carregar as bibliotecas necessárias.
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Atividade do Projeto da Unidade CineData Semana 25: O Mapa do Sucesso

# %%
# Escreva seu código aqui

# %% [markdown]
# # Gabarito / Expectativas de resposta – Orientações para o professor

# %% [markdown]
# ## Atividade do Projeto da Unidade CineData Semana 25: O Mapa do Sucesso

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('DADOSANO1C2B4S25A2A3A4_base_de_dados/base_de_filmes.csv')

# Selecionando colunas numéricas e calculando correlação
colunas_num = df[['orcamento_milhoes', 'faturamento_milhoes', 'nota_publico', 'duracao_min']]
matriz_corr = colunas_num.corr()

# Plotando
plt.figure(figsize=(8,6))
sns.heatmap(matriz_corr, annot=True, cmap='RdYlGn', fmt=".2f")
plt.title("Matriz de Correlação CineData")
plt.show()
