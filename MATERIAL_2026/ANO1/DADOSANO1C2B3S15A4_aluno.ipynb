# %% [markdown]
# <h1 style="text-align: center;">TÉCNICO EM CIÊNCIA DE DADOS</h1>
# <h1 style="text-align: center;">Roteiro de Atividade Prática</h1>
# <br>
# <br>
#
# **Componente:** Programação Aplicada à Ciência de Dados
# <br>
# **Unidade Curricular:** Manipulação e Estruturação de Dados
# <br>
# **Tema da Semana:** Importação de arquivos estruturados
# <br>
# **Semana 15**
# <br>
# **Aula 4:** Exercícios de importação de dados

# %% [markdown]
# <h2 align="center">Explorando Fontes de Dados: Da Importação à Inspeção</h2>

# %% [markdown]
# ## Objetivos da Atividade
# - Consolidar o uso das funções read_csv, read_excel e read_json da biblioteca Pandas para o carregamento de diferentes formatos de arquivos.
#
# - Validar a integridade e identificar os tipos de dados importados utilizando os métodos .head() e .info().
#
# - Iniciar a integração das bases de dados reais do projeto EcoMercado Analytics, preparando o terreno para futuras análises.

# %% [markdown]
# ## Lista de Materiais
# - Computador com **Anaconda (Jupyter Notebook)** ou **Visual Studio Code** instalado, com suporte a arquivos `.ipynb`.
# - Arquivo **"DADOSANO1C2B2S15A4_aluno.ipynb"** fornecido pelo professor.
# - Arquivo **"DADOSANO1C2B2S15A4_complementar1.csv"** fornecido pelo professor.
# - Arquivo **"DADOSANO1C2B2S15A4_produtos.xlsx"** fornecido pelo professor.
# - Arquivo **"DADOSANO1C2B2S15A4_vendas.csv"** fornecido pelo professor.
# - Arquivo **"DADOSANO1C2B2S15A4_estoque.json"** fornecido pelo professor.

# %% [markdown]
# ## Descrição do Projeto EcoMercado — Pipeline de Dados para Tomada de Decisão
#
# O EcoMercado possui dados espalhados em diferentes lugares (aplicativo, planilhas de estoque e logs do caixa). O dono não sabe quais produtos dão mais lucro e quais estão "encalhados" no estoque. O objetivo é ajudar o dono do negócio a entender suas vendas e reduzir o desperdício, gerando um relatório de inteligência de vendas.

# %% [markdown]
# ## Base Teórica
#
# A importação de dados é o primeiro e um dos mais cruciais passos em um pipeline de Ciência de Dados.
# No ecossistema Python, a biblioteca Pandas é a ferramenta padrão para essa tarefa.
# Ela oferece funções otimizadas como **pd.read_csv()**, **pd.read_excel()** e **pd.read_json()**, capazes de transformar arquivos brutos em DataFrames (tabelas estruturadas).
#
# Após a carga, é fundamental realizar uma inspeção inicial:
#
# **.head():** Exibe as primeiras 5 linhas, permitindo uma visualização rápida da estrutura.
#
# **.info():** Mostra um resumo técnico, incluindo o número de registros, valores nulos e o tipo de dado de cada coluna (inteiro, float, objeto/texto). Identificar se um número foi importado como texto, por exemplo, é vital para evitar erros em cálculos futuros.

# %% [markdown]
# ## Orientações para Responder às Atividades
#
# 1. **Quando a questão exigir que você rode um código:**
#    - Utilize o **Jupyter Notebook** para rodar o código.
#
# 2. **Quando for necessário digitar uma resposta:**
#    - Clique **duas vezes** na célula que contém a mensagem "Escreva sua resposta aqui". Após fazer isso, a célula se tornará **editável**.
#    - Não se preocupe, você não precisa saber Markdown para utilizá-la. Basta **digitar normalmente**.
#    - Após escrever sua resposta, clique no ícone **✓** (certo) no canto superior direito da célula para rodar e **salvar sua resposta**.
# 3. **Quando necessário utilizar um arquivo**
#    - Nas atividades, utilize os arquivos  fornecido pelo professor. Esses arquivos contém os dados necessários para realizar as análises e atividades propostas.
# ---

# %% [markdown]
# Execute o código abaixo para instalar as bibliotecas (se for necessário) para usar o Pandas com leitura de arquivos.

# %%
# %pip install pandas openpyxl

# %% [markdown]
# # Importação da Biblioteca Pandas

# %%
# Rode esta linha antes de começar a atividade para carregar a biblioteca pandas.
import pandas as pd

# %% [markdown]
# ## Cenário 1 — Simulando Monitoramento Meteorológico
#
# O arquivo **DADOSANO1C2B2S15A4_complementar1.csv** registra leituras horárias de uma estação climática. Ele contém dados de temperatura, umidade, pressão atmosférica e qualidade do ar. O objetivo é verificar se os sensores estão enviando dados completos e se os formatos (como data e números) estão corretos.
#
# **Crie um código em Python que:**
#
# 1. Leia o arquivo **DADOSANO1C2B2S15A4_complementar1.csv** com **df = pd.read_csv ("nome do arquivo")**.
#
# 2. Exibimos o cabeçalho para conferir se as colunas de temperatura e umidade foram importadas com **df.head()**.

# %%
# Escreva o código aqui

# %% [markdown]
# ## Atividade do Projeto da Unidade EcoMercado Semana 15: Primeiro Contato com os Dados Reais
# Chegou a hora de colocar as mãos nos dados do EcoMercado! Para iniciar a construção do pipeline de inteligência:
#
# **Objetivo da atividade**: Carregar corretamente diferentes bases de dados do EcoMercado e verificar se os dados foram importados sem erros.
#
# **Contexto do Projeto**: O EcoMercado possui dados separados em arquivos CSV, Excel e JSON. Antes de qualquer análise, é necessário garantir que esses dados foram carregados corretamente no sistema.
#
# ### Atividade Prática
#
# Utilizando a biblioteca Pandas, realize a carga dos seguintes arquivos  com **pd.read_csv()**, **pd.read_excel()** e **pd.read_json()**:
#
# - DADOSANO1C2B2S15A4_vendas.csv
#
# - DADOSANO1C2B2S15A4_produtos.xlsx
#
# - DADOSANO1C2B2S15A4_estoque.json
#
# Escolha uma dessas bases de dados e execute os seguintes passos:
#
# 1. Visualização: Exiba as 5 primeiras linhas (.head());
#
# 2. Tipagem: Analise os tipos de dados de cada coluna (.info());
#
# 3. Diagnóstico: Registre possíveis problemas encontrados em uma célula markdown, como:
#
#     - Colunas irrelevantes ou estranhas.
#
#     - Dados ausentes (nulos).
#
#     - Tipos de dados incorretos (ex: campos de preço formatados como texto).

# %%
# Escreva o código aqui

# %% [markdown]
# Registre possíveis problemas aqui
