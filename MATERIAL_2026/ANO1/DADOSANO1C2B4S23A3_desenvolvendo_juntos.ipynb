# %% [markdown]
# <h1 style="text-align: center;">TÉCNICO EM CIÊNCIA DE DADOS</h1>
# <h1 style="text-align: center;">Roteiro do Desenvolvendo Juntos</h1>
# <br>
# <br>
#
# **Componente:** Programação Aplicada à Ciência de Dados
# <br>
# **Unidade Curricular:** Bibliotecas de manipulação e visualização de dados
# <br>
# **Tema da Semana:** Customização de gráficos e elementos visuais com Matplotlib
# <br>
# **Semana 23**
# <br>
# **Aula 3:**  Relacionamento entre variáveis

# %% [markdown]
# <h2 align="center">Praticando Regressão e Pairplot
# </h2>

# %% [markdown]
# ## Objetivos
#
# - Criar gráficos de dispersão com linha de regressão.
#
# - Analisar múltiplas variáveis simultaneamente usando pairplot.

# %% [markdown]
# ## Lista de Materiais
# - Computador com **Anaconda (Jupyter Notebook)** ou **Visual Studio Code** instalado, com suporte a arquivos `.ipynb`.
# - Arquivo **"DADOSANO1C2B4S23A2_desenvolvendo_juntos.ipynb"** fornecido pelo professor.

# %% [markdown]
# Execute o código abaixo para instalar as bibliotecas (se for necessário) para a aula.

# %%
# %pip install seaborn matplotlib pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Prática Guiada Passo a Passo
#
# Cada etapa deve ser demonstrada pelo professor antes de os alunos repetirem, garantindo compreensão e conexão com a rotina de um profissional da área.

# %% [markdown]
# ### Etapa 1: Importação e Dados de Vendas
#
# Vamos criar um cenário onde analisamos o preço de um produto, o desconto aplicado e o volume de vendas.

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Criando dados fictícios
data = {
    'Preco': [50, 40, 30, 20, 10],
    'Desconto': [5, 10, 15, 20, 25],
    'Vendas': [100, 150, 200, 300, 450]
}
df = pd.DataFrame(data)
print("Dados prontos para análise!")
# Out:
# Dados prontos para análise!

# %% [markdown]
# ### Etapa 2: Visualizando a Regressão
#
# Vamos ver como o Desconto afeta as Vendas.

# %%
sns.regplot(x='Desconto', y='Vendas', data=df)
plt.title('Impacto do Desconto nas Vendas')
plt.show()

# %% [markdown]
# ### Etapa 3: Matriz de Relacionamentos
#
# Agora, vamos ver como todas as variáveis se relacionam entre si de uma só vez.

# %%
sns.pairplot(df)
plt.show()
