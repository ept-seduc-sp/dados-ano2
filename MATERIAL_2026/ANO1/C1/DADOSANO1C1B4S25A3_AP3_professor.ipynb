# %% [markdown]
# # Montando um notebook organizado

# %% [markdown]
# Nesta atividade vou usar texto, código e execução em sequência.

# %% [markdown]
# ## Cálculo simples

# %%
2+2
# Out:
# 4

# %% [markdown]
# ## Mensagem na tela

# %%
print("Olá,turma")
# Out:
# Olá,turma

# %% [markdown]
# ## Guardando uma informação

# %%
nome = "Ana"
print(nome)
# Out:
# Ana
