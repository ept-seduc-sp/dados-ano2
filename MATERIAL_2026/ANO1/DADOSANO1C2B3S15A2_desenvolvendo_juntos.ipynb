# %% [markdown]
# <h1 style="text-align: center;">TÉCNICO EM CIÊNCIA DE DADOS</h1>
# <h1 style="text-align: center;">Roteiro do Desenvolvendo Juntos</h1>
# <br>
# <br>
#
# **Componente:** Programação Aplicada à Ciência de Dados
# <br>
# **Unidade Curricular:** Manipulação e Estruturação de Dados
# <br>
# **Tema da Semana:** Importação de arquivos estruturados
# <br>
# **Semana 15**
# <br>
# **Aula 2:** Leitura de arquivos Excel e JSON

# %% [markdown]
# <h2 align="center">Praticando a Importação: Excel e JSON</h2>

# %% [markdown]
# ## Objetivos
# - Realizar a leitura de um arquivo Excel (.xlsx) identificando abas específicas.
# - Importar dados de um arquivo JSON e visualizar sua estrutura inicial.

# %% [markdown]
# ## Lista de Materiais
# - Computador com **Anaconda (Jupyter Notebook)** ou **Visual Studio Code** instalado, com suporte a arquivos `.ipynb`.
# - Arquivo **"DADOSANO1C2B2S15A2_desenvolvendo_juntos.ipynb"** fornecido pelo professor.
# - Arquivo **"DADOSANO1C2B2S15A2_auxiliar1.xlsx"** fornecido pelo professor.
# - Arquivo **"DADOSANO1C2B2S15A2_auxiliar2.json"** fornecido pelo professor.

# %% [markdown]
# Execute o código abaixo para instalar as bibliotecas (se for necessário) para usar o Pandas com leitura de arquivos.

# %%
# %pip install pandas openpyxl

# %% [markdown]
# ## Prática Guiada Passo a Passo
#
# ### Etapa 1: Preparando o ambiente
#
# O professor demonstrará como importar a biblioteca Pandas e verificar se a biblioteca openpyxl está disponível para ler arquivos Excel.

# %%
import pandas as pd

# %% [markdown]
# ### Etapa 2: Lendo o arquivo da "Firma" (Excel)
#
# Vamos usar o comando read_excel. O professor mostra como o parâmetro sheet_name é crucial quando a planilha tem várias abas (ex: Janeiro, Fevereiro, Março).

# %%
# O professor executa primeiro:
df_vendas = pd.read_excel('DADOSANO1C2B2S15A2_auxiliar1.xlsx', sheet_name='PEDIDOS')
df_vendas.head()

# %% [markdown]
# ### Etapa 3: Lendo o arquivo da "Web" (JSON)
#
# Agora, faremos o mesmo com o JSON. Note como a estrutura parece um dicionário (verifique o arquivo DADOSANO1C2B2S15A2_auxiliar2.json) mas o Pandas organiza em colunas automaticamente.
#
#
# Para completar a Etapa 3, o código ajustado deve conter o nome exato do arquivo (DADOSANO1C2B2S15A2_auxiliar2.json):
#
# ```python
# df_clientes = pd.read_json('nome do arquivo aqui')
#
# ```

# %%
# Aqui o professor conduzirá o exemplo acima.

# %% [markdown]
# - O Pandas interpreta as chaves do JSON como colunas.
#
# - Os valores são organizados automaticamente em linhas.
#
# - Você terá um DataFrame estruturado, pronto para análise.
