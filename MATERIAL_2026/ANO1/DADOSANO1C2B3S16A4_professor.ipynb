# %% [markdown]
# <h1 style="text-align: center;">TÉCNICO EM CIÊNCIA DE DADOS</h1>
# <h1 style="text-align: center;">Roteiro de Atividade Prática</h1>
# <br>
# <br>
#
# **Componente:** Programação Aplicada à Ciência de Dados
# <br>
# **Unidade Curricular:** Manipulação e Estruturação de Dados
# <br>
# **Tema da Semana:** Exportação de arquivos estruturados
# <br>
# **Semana 16**
# <br>
# **Aula 4:** Exercícios de exportação

# %% [markdown]
# <h2 align="center">Praticando a Exportação de Dados e Relatórios</h2>

# %% [markdown]
# ## Objetivos da Atividade
#
# - Consolidar o domínio técnico sobre os métodos de exportação de DataFrames para formatos CSV e Excel.
#
# - Desenvolver a autonomia na organização de arquivos processados em diretórios específicos.
#
# - Aplicar o conhecimento de manipulação de dados para gerar relatórios simples que auxiliem na tomada de decisão.

# %% [markdown]
# ## Lista de Materiais
# - Computador com **Anaconda (Jupyter Notebook)** ou **Visual Studio Code** instalado, com suporte a arquivos `.ipynb`.
# - Arquivo **"DADOSANO1C2B3S16A4_aluno.ipynb"** fornecido pelo professor.
# - Arquivo **"DADOSANO1C2B3S16A4_produtos.xlsx"** fornecido pelo professor.
# - Arquivo **"DADOSANO1C2B3S16A4_vendas.csv"** fornecido pelo professor.
# - Arquivo **"DADOSANO1C2B3S16A4_estoque.json"** fornecido pelo professor.

# %% [markdown]
# ## Descrição do Projeto EcoMercado — Pipeline de Dados para Tomada de Decisão
#
# O EcoMercado possui dados espalhados em diferentes lugares (aplicativo, planilhas de estoque e logs do caixa). O dono não sabe quais produtos dão mais lucro e quais estão "encalhados" no estoque. O objetivo é ajudar o dono do negócio a entender suas vendas e reduzir o desperdício, gerando um relatório de inteligência de vendas.

# %% [markdown]
# ## Base Teórica
#
# Exportar dados é a etapa final de um processo de tratamento. Após limpar e organizar as informações em um DataFrame (usando a biblioteca Pandas), precisamos salvar esse resultado para que outras pessoas ou sistemas possam utilizá-lo.
#
#  Os formatos mais comuns são o **CSV (leve e universal)** e o **Excel (ideal para relatórios administrativos)**. O comando principal que utilizamos é o **.to_csv()** ou **.to_excel()**, sempre lembrando de gerenciar o parâmetro index=False para evitar colunas desnecessárias de numeração.
#
# **Exemplos de Exportação**
#
# Ao exportar, o parâmetro index=False é fundamental para não criar uma coluna de índices automáticos no seu arquivo final.
#
# ```Python
# import pandas as pd
#
# # Criando um DataFrame de exemplo
# df = pd.DataFrame({'Produto': ['A', 'B'], 'Preço': [10, 20]})
#
# # 1. Exportar para CSV
# df.to_csv('dados_finais.csv', index=False, sep=';', encoding='utf-8')
#
# # 2. Exportar para Excel
# df.to_excel('relatorio.xlsx', index=False, sheet_name='Vendas')
# ```
# **Verificação de Arquivo**
#
# ```python
# import os
#
# caminho = 'dados_finais.csv'
#
# if os.path.exists(caminho):
#     print("O arquivo já existe!")
# else:
#     print("Arquivo não encontrado.")
# ```

# %% [markdown]
# ## Orientações para Responder às Atividades
#
# 1. **Quando a questão exigir que você rode um código:**
#    - Utilize o **Jupyter Notebook** para rodar o código.
#
# 2. **Quando for necessário digitar uma resposta:**
#    - Clique **duas vezes** na célula que contém a mensagem "Escreva sua resposta aqui". Após fazer isso, a célula se tornará **editável**.
#    - Não se preocupe, você não precisa saber Markdown para utilizá-la. Basta **digitar normalmente**.
#    - Após escrever sua resposta, clique no ícone **✓** (certo) no canto superior direito da célula para rodar e **salvar sua resposta**.
# 3. **Quando necessário utilizar um arquivo**
#    - Nas atividades, utilize os arquivos  fornecido pelo professor. Esses arquivos contém os dados necessários para realizar as análises e atividades propostas.
# ---

# %% [markdown]
# Execute o código abaixo para instalar as bibliotecas (se for necessário) para usar o Pandas com leitura de arquivos.

# %%
# %pip install pandas openpyxl

# %% [markdown]
# # Importação da Biblioteca Pandas

# %%
# Rode esta linha antes de começar a atividade para carregar a biblioteca pandas.
import pandas as pd

# %% [markdown]
# ## Cenário 1 — Exportação de Relatório de Vendas
#
# Imagine que você acabou de processar uma lista de vendas de uma loja de eletrônicos. Seus dados estão organizados em um DataFrame chamado df_vendas. Sua tarefa é:
#
# 1. Criar uma pasta chamada relatorios_finais.
#
# 2. Criar um dataframe df_vendas e exportar para um arquivo chamado vendas_semana_16.csv, garantindo que o separador seja ponto e vírgula (;) e que os índices não sejam exportados.
#
# 3. Exportar a mesma base para um arquivo Excel chamado vendas_consolidado.xlsx.

# %%
# Escreva o código aqui

# %% [markdown]
# ## Atividade do Projeto da Unidade EcoMercado Semana 16: Organizando a Saída do Pipeline
#
# **Objetivo da atividade**: importe os arquivos com dataframe criar uma pasta chamada base_de_dados e salvar os arquivos importado snessa base
#
# ### Atividade Prática
#
# 1. Importação das Bibliotecas: Inicie o script importando a biblioteca pandas para a manipulação de dados e a biblioteca os para a gestão de diretórios do sistema.
#
# 2. Utilizando a biblioteca Pandas, realize a carga dos seguintes arquivos  com **pd.read_csv()**, **pd.read_excel()** e **pd.read_json()**:
#
#     - DADOSANO1C2B3S15A4_vendas.csv
#
#     - DADOSANO1C2B3S15A4_produtos.xlsx
#
#     - DADOSANO1C2B3S15A4_estoque.json
#
# 3. Verificação do Diretório: Utilize o comando os.path.exists() para checar se a pasta base_de_dados já existe no seu ambiente de trabalho.
#
# 4. Tratamento de Condição:
#
#     - Caso a pasta exista: Utilize o comando print() para informar que o diretório já está presente.
#
#     - Caso não exista: Utilize o comando os.makedirs() para criar a pasta automaticamente.
#
# 5. Exportação dos Dados (Pipeline de Saída): Salve os DataFrames carregados dentro da nova pasta base_de_dados convertendo todos para csv:
#
#     - utilize to_csv(f'{pasta}/vendas.csv', index=False) para o arquivo de vendas.
#     - utilize to_csv(f'{pasta}/produtos.csv', index=False) para o arquivo de produtos.
#     - utilize to_csv(f'{pasta}/estoque.csv', index=False) para o arquivo de estoque.

# %%
# Escreva o código aqui

# %% [markdown]
# # Gabarito / Expectativas de resposta – Orientações para o professor

# %% [markdown]
# ## Cenário 1 — Exportação de Relatório de Vendas
#
# **Expectativa de Resposta**
#
# Espera-se que o aluno demonstre domínio na manipulação de arquivos do sistema operacional e na persistência de dados em diferentes formatos (CSV e Excel), compreendendo a importância de parâmetros como sep e index para a qualidade do relatório final.
#
#
# **Código exemplo esperado:**

# %%
import pandas as pd
import os

# 1. Criar a pasta
os.makedirs('relatorios_finais', exist_ok=True)

# Dados de exemplo para o DataFrame
df_vendas = pd.DataFrame({'Produto': ['Celular'], 'Valor': [2000]})

# 2. Exportar CSV (separador ; e sem índice)
df_vendas.to_csv('relatorios_finais/vendas_semana_16.csv', sep=';', index=False)

# 3. Exportar Excel
df_vendas.to_excel('relatorios_finais/vendas_consolidado.xlsx', index=False)

# %% [markdown]
# **Análise pedagógica**
#
# Esta atividade exercita a competência de "preparação para entrega", focando na interação entre Python e o sistema operacional e na parametrização técnica (delimitadores e índices), essencial para que o aluno transite da manipulação de dados puramente em memória para a geração de artefatos úteis e organizados no mundo real.

# %% [markdown]
# ## Atividade do Projeto da Unidade EcoMercado Semana 16: Organizando a Saída do Pipeline
#
# **Expectativa de entrega**
#
# O objetivo é que os alunos aprendam a manipular múltiplos formatos de arquivos simultaneamente e desenvolva a lógica de tratamento de diretórios, consolidando um pipeline que garanta a persistência organizada dos dados processados em um local centralizado.
#
# **Código exemplo esperado:**

# %%
import pandas as pd
import os

# 1. e 2. Importação e Carga
df_vendas = pd.read_csv('DADOSANO1C2B3S16A4_vendas.csv')
df_produtos = pd.read_excel('DADOSANO1C2B3S16A4_produtos.xlsx')
df_estoque = pd.read_json('DADOSANO1C2B3S16A4_estoque.json')

# 3. e 4. Verificação e Criação da Pasta
pasta = 'base_de_dados'
if os.path.exists(pasta):
    print(f"O diretório '{pasta}' já está presente.")
else:
    os.makedirs(pasta)

# 5. Exportação (Pipeline de Saída)
df_vendas.to_csv(f'{pasta}/vendas.csv', index=False)
df_produtos.to_csv(f'{pasta}/produtos.csv', index=False)
df_estoque.to_csv(f'{pasta}/estoque.csv', index=False)

# %% [markdown]
# **Análise pedagógica**
#
# Esta atividade trabalha o conceito de ETL (Extract, Transform, Load), focando na integração de fontes heterogêneas e na automação da infraestrutura de pastas; ao utilizar condicionais (if/else) para gerenciar diretórios, o aluno transita de um executor de comandos para um desenvolvedor de scripts resilientes, capazes de lidar com diferentes estados do ambiente de execução.
